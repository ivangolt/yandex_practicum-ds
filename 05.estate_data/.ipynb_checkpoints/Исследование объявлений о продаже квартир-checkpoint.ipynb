# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data =  pd.read_csv('C:/Users/Иван/test/real_estate_data.csv', sep='\t')
pd.set_option('display.max_columns', None)

data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 0      False          25.0      NaN  Санкт-Петербург           18863.0
# 1      False          11.0      2.0   посёлок Шушары           12817.0
# 2      False           8.3      0.0  Санкт-Петербург           21741.0
# 3      False           NaN      0.0  Санкт-Петербург           28098.0
# 4      False          41.0      NaN  Санкт-Петербург           31856.0
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0              16028.0               1.0          482.0               2.0
# 1              18603.0               0.0            NaN               0.0
# 2              13933.0               1.0           90.0               2.0
# 3               6800.0               2.0           84.0               3.0
# 4               8098.0               2.0          112.0               1.0
#
#    ponds_nearest  days_exposition
# 0          755.0              NaN
# 1            NaN             81.0
# 2          574.0            558.0
# 3          234.0            424.0
# 4           48.0            121.0

# %%
data.shape
# Out:
# (23699, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
#  15  airports_nearest      18157 non-null  float64
#  16  cityCenters_nearest   18180 non-null  float64
#  17  parks_around3000      18181 non-null  float64
#  18  parks_nearest         8079 non-null   float64
#  19  ponds_around3000      18181 non-null  float64
#  20  ponds_nearest         9110 non-null   float64
#  21  days_exposition       20518 non-null  float64
# dtypes: bool(2), float64(14), int64(3), object(3)
# memory usage: 3.7+ MB

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# std        6.597173     22.030445      4.885249      5.905438      1.071300
# min        1.000000      2.000000      1.000000      1.300000      0.000000
# 25%        5.000000     18.600000      2.000000      7.000000      0.000000
# 50%        9.000000     30.000000      4.000000      9.100000      1.000000
# 75%       16.000000     42.300000      8.000000     12.000000      2.000000
# max       60.000000    409.700000     33.000000    112.000000      5.000000
#
#        airports_nearest  cityCenters_nearest  parks_around3000  parks_nearest  \
# count      18157.000000         18180.000000      18181.000000    8079.000000
# mean       28793.672193         14191.277833          0.611408     490.804555
# std        12630.880622          8608.386210          0.802074     342.317995
# min            0.000000           181.000000          0.000000       1.000000
# 25%        18585.000000          9238.000000          0.000000     288.000000
# 50%        26726.000000         13098.500000          0.000000     455.000000
# 75%        37273.000000         16293.000000          1.000000     612.000000
# max        84869.000000         65968.000000          3.000000    3190.000000
#
#        ponds_around3000  ponds_nearest  days_exposition
# count      18181.000000    9110.000000     20518.000000
# mean           0.770255     517.980900       180.888634
# std            0.938346     277.720643       219.727988
# min            0.000000      13.000000         1.000000
# 25%            0.000000     294.000000        45.000000
# 50%            1.000000     502.000000        95.000000
# 75%            1.000000     729.000000       232.000000
# max            3.000000    1344.000000      1580.000000

# %%
data.hist(bins=10,figsize=(12,12))
# Out:
# array([[<Axes: title={'center': 'total_images'}>,
#         <Axes: title={'center': 'last_price'}>,
#         <Axes: title={'center': 'total_area'}>,
#         <Axes: title={'center': 'rooms'}>],
#        [<Axes: title={'center': 'ceiling_height'}>,
#         <Axes: title={'center': 'floors_total'}>,
#         <Axes: title={'center': 'living_area'}>,
#         <Axes: title={'center': 'floor'}>],
#        [<Axes: title={'center': 'kitchen_area'}>,
#         <Axes: title={'center': 'balcony'}>,
#         <Axes: title={'center': 'airports_nearest'}>,
#         <Axes: title={'center': 'cityCenters_nearest'}>],
#        [<Axes: title={'center': 'parks_around3000'}>,
#         <Axes: title={'center': 'parks_nearest'}>,
#         <Axes: title={'center': 'ponds_around3000'}>,
#         <Axes: title={'center': 'ponds_nearest'}>],
#        [<Axes: title={'center': 'days_exposition'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# # Предобработка данных

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Посчитаем процент пропущенных значений в столбцах.

# %%
((data.isnull().sum() / data.isnull().count()) * 100).round(3)
# Out:
# total_images             0.000
# last_price               0.000
# total_area               0.000
# first_day_exposition     0.000
# rooms                    0.000
# ceiling_height          38.799
# floors_total             0.363
# living_area              8.030
# floor                    0.000
# is_apartment            88.291
# studio                   0.000
# open_plan                0.000
# kitchen_area             9.612
# balcony                 48.605
# locality_name            0.207
# airports_nearest        23.385
# cityCenters_nearest     23.288
# parks_around3000        23.284
# parks_nearest           65.910
# ponds_around3000        23.284
# ponds_nearest           61.560
# days_exposition         13.423
# dtype: float64

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 0      False          25.0      NaN  Санкт-Петербург           18863.0
# 1      False          11.0      2.0   посёлок Шушары           12817.0
# 2      False           8.3      0.0  Санкт-Петербург           21741.0
# 3      False           NaN      0.0  Санкт-Петербург           28098.0
# 4      False          41.0      NaN  Санкт-Петербург           31856.0
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0              16028.0               1.0          482.0               2.0
# 1              18603.0               0.0            NaN               0.0
# 2              13933.0               1.0           90.0               2.0
# 3               6800.0               2.0           84.0               3.0
# 4               8098.0               2.0          112.0               1.0
#
#    ponds_nearest  days_exposition
# 0          755.0              NaN
# 1            NaN             81.0
# 2          574.0            558.0
# 3          234.0            424.0
# 4           48.0            121.0

# %% [markdown]
# Для числовых переменных заменим пустые значения медианой по столбцу.

# %%
numeric_missing_value_columns = ['ceiling_height', 'floors_total', 'living_area', 'kitchen_area', 'balcony', 'airports_nearest', 
                   'cityCenters_nearest', 'parks_around3000', 'parks_nearest', 'days_exposition', 'ponds_around3000',
                                 'ponds_nearest']

for column in numeric_missing_value_columns:
    data[column].fillna(data[column].median(), inplace=True)

# %% [markdown]
# В категориальном признаке 'locality_name' пропуски заменим модой по столбцу.

# %%
data['locality_name'] = data['locality_name'].fillna(data['locality_name'].mode()[0])

# %% [markdown]
# Столбец 'is_apartment' удалим так как он содержит слишком большой процент (~ 88%) пропущенных значений.

# %%
data.drop('is_apartment',axis= 1,inplace=True)

# %%
data.isna().sum()
# Out:
# total_images            0
# last_price              0
# total_area              0
# first_day_exposition    0
# rooms                   0
# ceiling_height          0
# floors_total            0
# living_area             0
# floor                   0
# studio                  0
# open_plan               0
# kitchen_area            0
# balcony                 0
# locality_name           0
# airports_nearest        0
# cityCenters_nearest     0
# parks_around3000        0
# parks_nearest           0
# ponds_around3000        0
# ponds_nearest           0
# days_exposition         0
# dtype: int64

# %%
cols = data.columns 

#красный для пропущенных данных и зеленый для не пропущенных
colours = ['#FF5733', '#00FF00']
sns.heatmap(data[cols].isnull(), cmap=sns.color_palette(colours))
plt.show()

# %% [markdown]
# Подсчитаем явные дубликаты.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Изменим тип данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   studio                23699 non-null  bool
#  10  open_plan             23699 non-null  bool
#  11  kitchen_area          23699 non-null  float64
#  12  balcony               23699 non-null  float64
#  13  locality_name         23699 non-null  object
#  14  airports_nearest      23699 non-null  float64
#  15  cityCenters_nearest   23699 non-null  float64
#  16  parks_around3000      23699 non-null  float64
#  17  parks_nearest         23699 non-null  float64
#  18  ponds_around3000      23699 non-null  float64
#  19  ponds_nearest         23699 non-null  float64
#  20  days_exposition       23699 non-null  float64
# dtypes: bool(2), float64(14), int64(3), object(2)
# memory usage: 3.5+ MB

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 0            2.70          16.0         51.0      8   False      False
# 1            2.65          11.0         18.6      1   False      False
# 2            2.65           5.0         34.3      4   False      False
# 3            2.65          14.0         30.0      9   False      False
# 4            3.03          14.0         32.0     13   False      False
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      1.0  Санкт-Петербург           18863.0
# 1          11.0      2.0   посёлок Шушары           12817.0
# 2           8.3      0.0  Санкт-Петербург           21741.0
# 3           9.1      0.0  Санкт-Петербург           28098.0
# 4          41.0      1.0  Санкт-Петербург           31856.0
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0              16028.0               1.0          482.0               2.0
# 1              18603.0               0.0          455.0               0.0
# 2              13933.0               1.0           90.0               2.0
# 3               6800.0               2.0           84.0               3.0
# 4               8098.0               2.0          112.0               1.0
#
#    ponds_nearest  days_exposition
# 0          755.0             95.0
# 1          502.0             81.0
# 2          574.0            558.0
# 3          234.0            424.0
# 4           48.0            121.0

# %% [markdown]
# Для столбцов  'last_price', 'floors_total', 'balcony', 'aiports_nearest', 'cityCenters_nearest', 'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'days_exposition' изменим тип данных с float на int с целью экономии памяти и удобства анализа.

# %%
transform_to_int_list = ['last_price', 'floors_total', 'balcony', 'airports_nearest', 'cityCenters_nearest',
                        'parks_nearest','parks_around3000', 'ponds_around3000', 'ponds_nearest', 'days_exposition']

for column in transform_to_int_list:
    data[column] = data[column].astype('int')

# %%
data.dtypes
# Out:
# total_images              int64
# last_price                int32
# total_area              float64
# first_day_exposition     object
# rooms                     int64
# ceiling_height          float64
# floors_total              int32
# living_area             float64
# floor                     int64
# studio                     bool
# open_plan                  bool
# kitchen_area            float64
# balcony                   int32
# locality_name            object
# airports_nearest          int32
# cityCenters_nearest       int32
# parks_around3000          int32
# parks_nearest             int32
# ponds_around3000          int32
# ponds_nearest             int32
# days_exposition           int32
# dtype: object

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0  2019-03-07T00:00:00      3
# 1             7     3350000        40.4  2018-12-04T00:00:00      1
# 2            10     5196000        56.0  2015-08-20T00:00:00      2
# 3             0    64900000       159.0  2015-07-24T00:00:00      3
# 4             2    10000000       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 0            2.70            16         51.0      8   False      False
# 1            2.65            11         18.6      1   False      False
# 2            2.65             5         34.3      4   False      False
# 3            2.65            14         30.0      9   False      False
# 4            3.03            14         32.0     13   False      False
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0        1  Санкт-Петербург             18863
# 1          11.0        2   посёлок Шушары             12817
# 2           8.3        0  Санкт-Петербург             21741
# 3           9.1        0  Санкт-Петербург             28098
# 4          41.0        1  Санкт-Петербург             31856
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0                16028                 1            482                 2
# 1                18603                 0            455                 0
# 2                13933                 1             90                 2
# 3                 6800                 2             84                 3
# 4                 8098                 2            112                 1
#
#    ponds_nearest  days_exposition
# 0            755               95
# 1            502               81
# 2            574              558
# 3            234              424
# 4             48              121

# %% [markdown]
# Преобразуем столбец  first_day_exposition в формат datetime.

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 0            2.70            16         51.0      8   False      False
# 1            2.65            11         18.6      1   False      False
# 2            2.65             5         34.3      4   False      False
# 3            2.65            14         30.0      9   False      False
# 4            3.03            14         32.0     13   False      False
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0        1  Санкт-Петербург             18863
# 1          11.0        2   посёлок Шушары             12817
# 2           8.3        0  Санкт-Петербург             21741
# 3           9.1        0  Санкт-Петербург             28098
# 4          41.0        1  Санкт-Петербург             31856
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0                16028                 1            482                 2
# 1                18603                 0            455                 0
# 2                13933                 1             90                 2
# 3                 6800                 2             84                 3
# 4                 8098                 2            112                 1
#
#    ponds_nearest  days_exposition
# 0            755               95
# 1            502               81
# 2            574              558
# 3            234              424
# 4             48              121

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  int32
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  int32
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   studio                23699 non-null  bool
#  10  open_plan             23699 non-null  bool
#  11  kitchen_area          23699 non-null  float64
#  12  balcony               23699 non-null  int32
#  13  locality_name         23699 non-null  object
#  14  airports_nearest      23699 non-null  int32
#  15  cityCenters_nearest   23699 non-null  int32
#  16  parks_around3000      23699 non-null  int32
#  17  parks_nearest         23699 non-null  int32
#  18  ponds_around3000      23699 non-null  int32
#  19  ponds_nearest         23699 non-null  int32
#  20  days_exposition       23699 non-null  int32
# dtypes: bool(2), datetime64[ns](1), float64(4), int32(10), int64(3), object(1)
# memory usage: 2.6+ MB

# %% [markdown]
# Устраним неявные дубликаты переменной locality_name.

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
#        'городской посёлок Свирьстрой', 'городской посёлок Советский',
#        'городской посёлок Фёдоровское', 'городской посёлок Янино-1',
#        'деревня Агалатово', 'деревня Аро', 'деревня Батово',
#        'деревня Бегуницы', 'деревня Белогорка', 'деревня Большая Вруда',
#        'деревня Большая Пустомержа', 'деревня Большие Колпаны',
#        'деревня Большое Рейзино', 'деревня Большой Сабск', 'деревня Бор',
#        'деревня Борисова Грива', 'деревня Ваганово', 'деревня Вартемяги',
#        'деревня Вахнова Кара', 'деревня Выскатка', 'деревня Гарболово',
#        'деревня Глинка', 'деревня Горбунки', 'деревня Гостилицы',
#        'деревня Заклинье', 'деревня Заневка', 'деревня Зимитицы',
#        'деревня Извара', 'деревня Иссад', 'деревня Калитино',
#        'деревня Кальтино', 'деревня Камышовка', 'деревня Каськово',
#        'деревня Келози', 'деревня Кипень', 'деревня Кисельня',
#        'деревня Колтуши', 'деревня Коркино', 'деревня Котлы',
#        'деревня Кривко', 'деревня Кудрово', 'деревня Кузьмолово',
#        'деревня Курковицы', 'деревня Куровицы', 'деревня Куттузи',
#        'деревня Лаврики', 'деревня Лаголово', 'деревня Лампово',
#        'деревня Лесколово', 'деревня Лопухинка', 'деревня Лупполово',
#        'деревня Малая Романовка', 'деревня Малое Верево',
#        'деревня Малое Карлино', 'деревня Малые Колпаны',
#        'деревня Мануйлово', 'деревня Меньково', 'деревня Мины',
#        'деревня Мистолово', 'деревня Ненимяки', 'деревня Нижние Осельки',
#        'деревня Нижняя', 'деревня Низино', 'деревня Новое Девяткино',
#        'деревня Новолисино', 'деревня Нурма', 'деревня Оржицы',
#        'деревня Парицы', 'деревня Пельгора', 'деревня Пеники',
#        'деревня Пижма', 'деревня Пикколово', 'деревня Пудомяги',
#        'деревня Пустынка', 'деревня Пчева', 'деревня Рабитицы',
#        'деревня Разбегаево', 'деревня Раздолье', 'деревня Разметелево',
#        'деревня Рапполово', 'деревня Реброво', 'деревня Русско',
#        'деревня Сижно', 'деревня Снегирёвка', 'деревня Старая',
#        'деревня Старая Пустошь', 'деревня Старое Хинколово',
#        'деревня Старополье', 'деревня Старосиверская',
#        'деревня Старые Бегуницы', 'деревня Суоранда',
#        'деревня Сяськелево', 'деревня Тарасово', 'деревня Терпилицы',
#        'деревня Тихковицы', 'деревня Тойворово', 'деревня Торосово',
#        'деревня Торошковичи', 'деревня Трубников Бор',
#        'деревня Фалилеево', 'деревня Фёдоровское', 'деревня Хапо-Ое',
#        'деревня Хязельки', 'деревня Чудской Бор', 'деревня Шпаньково',
#        'деревня Щеглово', 'деревня Юкки', 'деревня Ялгино',
#        'деревня Яльгелево', 'деревня Ям-Тесово',
#        'коттеджный поселок Кивеннапа Север', 'коттеджный поселок Счастье',
#        'коттеджный посёлок Лесное', 'поселок Аннино', 'поселок Барышево',
#        'поселок Бугры', 'поселок Возрождение', 'поселок Войсковицы',
#        'поселок Володарское', 'поселок Гаврилово', 'поселок Гарболово',
#        'поселок Гладкое', 'поселок Глажево', 'поселок Глебычево',
#        'поселок Гончарово', 'поселок Громово', 'поселок Дружноселье',
#        'поселок Елизаветино', 'поселок Жилгородок', 'поселок Жилпосёлок',
#        'поселок Житково', 'поселок Заводской', 'поселок Запорожское',
#        'поселок Зимитицы', 'поселок Ильичёво', 'поселок Калитино',
#        'поселок Каложицы', 'поселок Кингисеппский', 'поселок Кирпичное',
#        'поселок Кобралово', 'поселок Кобринское', 'поселок Коммунары',
#        'поселок Коробицыно', 'поселок Котельский',
#        'поселок Красная Долина', 'поселок Красносельское',
#        'поселок Лесное', 'поселок Лисий Нос', 'поселок Лукаши',
#        'поселок Любань', 'поселок Мельниково', 'поселок Мичуринское',
#        'поселок Молодцово', 'поселок Мурино', 'поселок Новый Свет',
#        'поселок Новый Учхоз', 'поселок Оредеж',
#        'поселок Пансионат Зелёный Бор', 'поселок Первомайское',
#        'поселок Перово', 'поселок Петровское', 'поселок Победа',
#        'поселок Поляны', 'поселок Почап', 'поселок Починок',
#        'поселок Пушное', 'поселок Пчевжа', 'поселок Рабитицы',
#        'поселок Романовка', 'поселок Ромашки', 'поселок Рябово',
#        'поселок Севастьяново', 'поселок Селезнёво', 'поселок Сельцо',
#        'поселок Семиозерье', 'поселок Семрино', 'поселок Серебрянский',
#        'поселок Совхозный', 'поселок Старая Малукса',
#        'поселок Стеклянный', 'поселок Сумино', 'поселок Суходолье',
#        'поселок Тельмана', 'поселок Терволово', 'поселок Торковичи',
#        'поселок Тёсово-4', 'поселок Углово', 'поселок Усть-Луга',
#        'поселок Ушаки', 'поселок Цвелодубово', 'поселок Цвылёво',
#        'поселок городского типа Большая Ижора',
#        'поселок городского типа Вырица',
#        'поселок городского типа Дружная Горка',
#        'поселок городского типа Дубровка',
#        'поселок городского типа Ефимовский',
#        'поселок городского типа Кондратьево',
#        'поселок городского типа Красный Бор',
#        'поселок городского типа Кузьмоловский',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Лесогорский',
#        'поселок городского типа Назия',
#        'поселок городского типа Никольский',
#        'поселок городского типа Приладожский',
#        'поселок городского типа Рахья', 'поселок городского типа Рощино',
#        'поселок городского типа Рябово',
#        'поселок городского типа Синявино',
#        'поселок городского типа Советский',
#        'поселок городского типа Токсово',
#        'поселок городского типа Форносово',
#        'поселок городского типа имени Свердлова',
#        'поселок станции Вещево', 'поселок станции Корнево',
#        'поселок станции Лужайка', 'поселок станции Приветнинское',
#        'посёлок Александровская', 'посёлок Алексеевка', 'посёлок Аннино',
#        'посёлок Белоостров', 'посёлок Бугры', 'посёлок Возрождение',
#        'посёлок Войскорово', 'посёлок Высокоключевой',
#        'посёлок Гаврилово', 'посёлок Дзержинского', 'посёлок Жилгородок',
#        'посёлок Ильичёво', 'посёлок Кикерино', 'посёлок Кобралово',
#        'посёлок Коробицыно', 'посёлок Левашово', 'посёлок Ленинское',
#        'посёлок Лисий Нос', 'посёлок Мельниково', 'посёлок Металлострой',
#        'посёлок Мичуринское', 'посёлок Молодёжное', 'посёлок Мурино',
#        'посёлок Мыза-Ивановка', 'посёлок Новогорелово',
#        'посёлок Новый Свет', 'посёлок Пансионат Зелёный Бор',
#        'посёлок Парголово', 'посёлок Перово', 'посёлок Песочный',
#        'посёлок Петро-Славянка', 'посёлок Петровское',
#        'посёлок Платформа 69-й километр', 'посёлок Плодовое',
#        'посёлок Плоское', 'посёлок Победа', 'посёлок Поляны',
#        'посёлок Понтонный', 'посёлок Пригородный', 'посёлок Пудость',
#        'посёлок Репино', 'посёлок Ропша', 'посёлок Сапёрное',
#        'посёлок Сапёрный', 'посёлок Сосново', 'посёлок Старая Малукса',
#        'посёлок Стеклянный', 'посёлок Стрельна', 'посёлок Суйда',
#        'посёлок Сумино', 'посёлок Тельмана', 'посёлок Терволово',
#        'посёлок Торфяное', 'посёлок Усть-Ижора', 'посёлок Усть-Луга',
#        'посёлок Форт Красная Горка', 'посёлок Шугозеро', 'посёлок Шушары',
#        'посёлок Щеглово', 'посёлок городского типа Важины',
#        'посёлок городского типа Вознесенье',
#        'посёлок городского типа Вырица',
#        'посёлок городского типа Красный Бор',
#        'посёлок городского типа Кузнечное',
#        'посёлок городского типа Кузьмоловский',
#        'посёлок городского типа Лебяжье', 'посёлок городского типа Мга',
#        'посёлок городского типа Павлово',
#        'посёлок городского типа Рощино', 'посёлок городского типа Рябово',
#        'посёлок городского типа Сиверский',
#        'посёлок городского типа Тайцы', 'посёлок городского типа Токсово',
#        'посёлок городского типа Ульяновка',
#        'посёлок городского типа Форносово',
#        'посёлок городского типа имени Морозова',
#        'посёлок городского типа имени Свердлова',
#        'посёлок при железнодорожной станции Вещево',
#        'посёлок при железнодорожной станции Приветнинское',
#        'посёлок станции Громово', 'посёлок станции Свирь',
#        'садоводческое некоммерческое товарищество Лесная Поляна',
#        'садовое товарищество Новая Ропша',
#        'садовое товарищество Приладожский', 'садовое товарищество Рахья',
#        'садовое товарищество Садко', 'село Копорье', 'село Никольское',
#        'село Павлово', 'село Паша', 'село Путилово', 'село Рождествено',
#        'село Русско-Высоцкое', 'село Старая Ладога', 'село Шум'],
#       dtype=object)

# %%
replacements_values = {
    'городской поселок Большая Ижора': 'городской посёлок Большая Ижора',
    'городской поселок Яннино-1': 'городской посёлок Яннино-1',
    'поселок': 'посёлок',
    'городской посёлок': 'посёлок городского типа'
}

data['locality_name'] = data['locality_name'].replace(replacements_values, regex=True)

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской посёлок Большая Ижора', 'городской посёлок Янино-1',
#        'деревня Агалатово', 'деревня Аро', 'деревня Батово',
#        'деревня Бегуницы', 'деревня Белогорка', 'деревня Большая Вруда',
#        'деревня Большая Пустомержа', 'деревня Большие Колпаны',
#        'деревня Большое Рейзино', 'деревня Большой Сабск', 'деревня Бор',
#        'деревня Борисова Грива', 'деревня Ваганово', 'деревня Вартемяги',
#        'деревня Вахнова Кара', 'деревня Выскатка', 'деревня Гарболово',
#        'деревня Глинка', 'деревня Горбунки', 'деревня Гостилицы',
#        'деревня Заклинье', 'деревня Заневка', 'деревня Зимитицы',
#        'деревня Извара', 'деревня Иссад', 'деревня Калитино',
#        'деревня Кальтино', 'деревня Камышовка', 'деревня Каськово',
#        'деревня Келози', 'деревня Кипень', 'деревня Кисельня',
#        'деревня Колтуши', 'деревня Коркино', 'деревня Котлы',
#        'деревня Кривко', 'деревня Кудрово', 'деревня Кузьмолово',
#        'деревня Курковицы', 'деревня Куровицы', 'деревня Куттузи',
#        'деревня Лаврики', 'деревня Лаголово', 'деревня Лампово',
#        'деревня Лесколово', 'деревня Лопухинка', 'деревня Лупполово',
#        'деревня Малая Романовка', 'деревня Малое Верево',
#        'деревня Малое Карлино', 'деревня Малые Колпаны',
#        'деревня Мануйлово', 'деревня Меньково', 'деревня Мины',
#        'деревня Мистолово', 'деревня Ненимяки', 'деревня Нижние Осельки',
#        'деревня Нижняя', 'деревня Низино', 'деревня Новое Девяткино',
#        'деревня Новолисино', 'деревня Нурма', 'деревня Оржицы',
#        'деревня Парицы', 'деревня Пельгора', 'деревня Пеники',
#        'деревня Пижма', 'деревня Пикколово', 'деревня Пудомяги',
#        'деревня Пустынка', 'деревня Пчева', 'деревня Рабитицы',
#        'деревня Разбегаево', 'деревня Раздолье', 'деревня Разметелево',
#        'деревня Рапполово', 'деревня Реброво', 'деревня Русско',
#        'деревня Сижно', 'деревня Снегирёвка', 'деревня Старая',
#        'деревня Старая Пустошь', 'деревня Старое Хинколово',
#        'деревня Старополье', 'деревня Старосиверская',
#        'деревня Старые Бегуницы', 'деревня Суоранда',
#        'деревня Сяськелево', 'деревня Тарасово', 'деревня Терпилицы',
#        'деревня Тихковицы', 'деревня Тойворово', 'деревня Торосово',
#        'деревня Торошковичи', 'деревня Трубников Бор',
#        'деревня Фалилеево', 'деревня Фёдоровское', 'деревня Хапо-Ое',
#        'деревня Хязельки', 'деревня Чудской Бор', 'деревня Шпаньково',
#        'деревня Щеглово', 'деревня Юкки', 'деревня Ялгино',
#        'деревня Яльгелево', 'деревня Ям-Тесово',
#        'коттеджный посёлок Кивеннапа Север', 'коттеджный посёлок Лесное',
#        'коттеджный посёлок Счастье', 'посёлок Александровская',
#        'посёлок Алексеевка', 'посёлок Аннино', 'посёлок Барышево',
#        'посёлок Белоостров', 'посёлок Бугры', 'посёлок Возрождение',
#        'посёлок Войсковицы', 'посёлок Войскорово', 'посёлок Володарское',
#        'посёлок Высокоключевой', 'посёлок Гаврилово', 'посёлок Гарболово',
#        'посёлок Гладкое', 'посёлок Глажево', 'посёлок Глебычево',
#        'посёлок Гончарово', 'посёлок Громово', 'посёлок Дзержинского',
#        'посёлок Дружноселье', 'посёлок Елизаветино', 'посёлок Жилгородок',
#        'посёлок Жилпосёлок', 'посёлок Житково', 'посёлок Заводской',
#        'посёлок Запорожское', 'посёлок Зимитицы', 'посёлок Ильичёво',
#        'посёлок Калитино', 'посёлок Каложицы', 'посёлок Кикерино',
#        'посёлок Кингисеппский', 'посёлок Кирпичное', 'посёлок Кобралово',
#        'посёлок Кобринское', 'посёлок Коммунары', 'посёлок Коробицыно',
#        'посёлок Котельский', 'посёлок Красная Долина',
#        'посёлок Красносельское', 'посёлок Левашово', 'посёлок Ленинское',
#        'посёлок Лесное', 'посёлок Лисий Нос', 'посёлок Лукаши',
#        'посёлок Любань', 'посёлок Мельниково', 'посёлок Металлострой',
#        'посёлок Мичуринское', 'посёлок Молодцово', 'посёлок Молодёжное',
#        'посёлок Мурино', 'посёлок Мыза-Ивановка', 'посёлок Новогорелово',
#        'посёлок Новый Свет', 'посёлок Новый Учхоз', 'посёлок Оредеж',
#        'посёлок Пансионат Зелёный Бор', 'посёлок Парголово',
#        'посёлок Первомайское', 'посёлок Перово', 'посёлок Песочный',
#        'посёлок Петро-Славянка', 'посёлок Петровское',
#        'посёлок Платформа 69-й километр', 'посёлок Плодовое',
#        'посёлок Плоское', 'посёлок Победа', 'посёлок Поляны',
#        'посёлок Понтонный', 'посёлок Почап', 'посёлок Починок',
#        'посёлок Пригородный', 'посёлок Пудость', 'посёлок Пушное',
#        'посёлок Пчевжа', 'посёлок Рабитицы', 'посёлок Репино',
#        'посёлок Романовка', 'посёлок Ромашки', 'посёлок Ропша',
#        'посёлок Рябово', 'посёлок Сапёрное', 'посёлок Сапёрный',
#        'посёлок Севастьяново', 'посёлок Селезнёво', 'посёлок Сельцо',
#        'посёлок Семиозерье', 'посёлок Семрино', 'посёлок Серебрянский',
#        'посёлок Совхозный', 'посёлок Сосново', 'посёлок Старая Малукса',
#        'посёлок Стеклянный', 'посёлок Стрельна', 'посёлок Суйда',
#        'посёлок Сумино', 'посёлок Суходолье', 'посёлок Тельмана',
#        'посёлок Терволово', 'посёлок Торковичи', 'посёлок Торфяное',
#        'посёлок Тёсово-4', 'посёлок Углово', 'посёлок Усть-Ижора',
#        'посёлок Усть-Луга', 'посёлок Ушаки', 'посёлок Форт Красная Горка',
#        'посёлок Цвелодубово', 'посёлок Цвылёво', 'посёлок Шугозеро',
#        'посёлок Шушары', 'посёлок Щеглово',
#        'посёлок городского типа Большая Ижора',
#        'посёлок городского типа Будогощь',
#        'посёлок городского типа Важины',
#        'посёлок городского типа Виллози',
#        'посёлок городского типа Вознесенье',
#        'посёлок городского типа Вырица',
#        'посёлок городского типа Дружная Горка',
#        'посёлок городского типа Дубровка',
#        'посёлок городского типа Ефимовский',
#        'посёлок городского типа Кондратьево',
#        'посёлок городского типа Красный Бор',
#        'посёлок городского типа Кузнечное',
#        'посёлок городского типа Кузьмоловский',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Лесогорский',
#        'посёлок городского типа Мга', 'посёлок городского типа Назия',
#        'посёлок городского типа Никольский',
#        'посёлок городского типа Новоселье',
#        'посёлок городского типа Павлово',
#        'посёлок городского типа Приладожский',
#        'посёлок городского типа Рахья', 'посёлок городского типа Рощино',
#        'посёлок городского типа Рябово',
#        'посёлок городского типа Свирьстрой',
#        'посёлок городского типа Сиверский',
#        'посёлок городского типа Синявино',
#        'посёлок городского типа Советский',
#        'посёлок городского типа Тайцы', 'посёлок городского типа Токсово',
#        'посёлок городского типа Ульяновка',
#        'посёлок городского типа Форносово',
#        'посёлок городского типа Фёдоровское',
#        'посёлок городского типа Янино-1',
#        'посёлок городского типа имени Морозова',
#        'посёлок городского типа имени Свердлова',
#        'посёлок при железнодорожной станции Вещево',
#        'посёлок при железнодорожной станции Приветнинское',
#        'посёлок станции Вещево', 'посёлок станции Громово',
#        'посёлок станции Корнево', 'посёлок станции Лужайка',
#        'посёлок станции Приветнинское', 'посёлок станции Свирь',
#        'садоводческое некоммерческое товарищество Лесная Поляна',
#        'садовое товарищество Новая Ропша',
#        'садовое товарищество Приладожский', 'садовое товарищество Рахья',
#        'садовое товарищество Садко', 'село Копорье', 'село Никольское',
#        'село Павлово', 'село Паша', 'село Путилово', 'село Рождествено',
#        'село Русско-Высоцкое', 'село Старая Ладога', 'село Шум'],
#       dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  int32
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  int32
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   studio                23699 non-null  bool
#  10  open_plan             23699 non-null  bool
#  11  kitchen_area          23699 non-null  float64
#  12  balcony               23699 non-null  int32
#  13  locality_name         23699 non-null  object
#  14  airports_nearest      23699 non-null  int32
#  15  cityCenters_nearest   23699 non-null  int32
#  16  parks_around3000      23699 non-null  int32
#  17  parks_nearest         23699 non-null  int32
#  18  ponds_around3000      23699 non-null  int32
#  19  ponds_nearest         23699 non-null  int32
#  20  days_exposition       23699 non-null  int32
# dtypes: bool(2), datetime64[ns](1), float64(4), int32(10), int64(3), object(1)
# memory usage: 2.6+ MB

# %% [markdown]
# Устраним редкие и аномальные значения во всех столбцах.

# %%
cols = data.columns 

#красный для пропущенных данных и зеленый для не пропущенных
colours = ['#FF5733', '#00FF00']
sns.heatmap(data[cols].isnull(), cmap=sns.color_palette(colours))
plt.show()

# %%
numeric_columns = data.select_dtypes(include=[int, float])


# Проход по каждому числовому столбцу и построение boxplot'а
for column in numeric_columns.columns:
    plt.boxplot(numeric_columns[column])
    plt.title(column)
    plt.figure(figsize=(3, 3)) 
    plt.show()

# %%
data.hist(bins=12, figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'total_images'}>,
#         <Axes: title={'center': 'last_price'}>,
#         <Axes: title={'center': 'total_area'}>,
#         <Axes: title={'center': 'first_day_exposition'}>],
#        [<Axes: title={'center': 'rooms'}>,
#         <Axes: title={'center': 'ceiling_height'}>,
#         <Axes: title={'center': 'floors_total'}>,
#         <Axes: title={'center': 'living_area'}>],
#        [<Axes: title={'center': 'floor'}>,
#         <Axes: title={'center': 'kitchen_area'}>,
#         <Axes: title={'center': 'balcony'}>,
#         <Axes: title={'center': 'airports_nearest'}>],
#        [<Axes: title={'center': 'cityCenters_nearest'}>,
#         <Axes: title={'center': 'parks_around3000'}>,
#         <Axes: title={'center': 'parks_nearest'}>,
#         <Axes: title={'center': 'ponds_around3000'}>],
#        [<Axes: title={'center': 'ponds_nearest'}>,
#         <Axes: title={'center': 'days_exposition'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    23699.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.724358
# std        5.682529  1.088701e+07     35.654083      1.078405        0.988298
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.700000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23699.000000  23699.000000  23699.000000  23699.000000  23699.000000
# mean      10.667750     34.099892      5.892358     10.428526      1.077134
# std        6.585961     21.162096      4.885249      5.631126      0.771655
# min        1.000000      2.000000      1.000000      1.300000      0.000000
# 25%        5.000000     19.000000      2.000000      7.400000      1.000000
# 50%        9.000000     30.000000      4.000000      9.100000      1.000000
# 75%       16.000000     41.100000      8.000000     11.440000      1.000000
# max       60.000000    409.700000     33.000000    112.000000      5.000000
#
#        airports_nearest  cityCenters_nearest  parks_around3000  parks_nearest  \
# count      23699.000000         23699.000000      23699.000000   23699.000000
# mean       28310.148023         13936.676358          0.469049     467.205789
# std        11090.330161          7553.792559          0.748534     200.579309
# min            0.000000           181.000000          0.000000       1.000000
# 25%        21183.000000         10927.000000          0.000000     455.000000
# 50%        26726.000000         13098.000000          0.000000     455.000000
# 75%        34327.000000         15248.500000          1.000000     455.000000
# max        84869.000000         65968.000000          3.000000    3190.000000
#
#        ponds_around3000  ponds_nearest  days_exposition
# count      23699.000000   23699.000000     23699.000000
# mean           0.823748     508.143128       169.360226
# std            0.827588     172.357382       206.535633
# min            0.000000      13.000000         1.000000
# 25%            0.000000     502.000000        45.000000
# 50%            1.000000     502.000000        95.000000
# 75%            1.000000     502.000000       199.000000
# max            3.000000    1344.000000      1580.000000

# %% [markdown]
# **total_images** - Отфильтруем строки в которых количество фотографий меньше 30, так как другие значения редкие\
#
# **last_price** - максимальное значение явно больше медианного значения, что может говорить о выбросе, поэтому в этом столбце отфильтруем данные по межквартильному размаху.\
#
# **total_area** - в этом столбце отфильтруем значения площади от 10 до 400 кв.м , так как наиболее возможные границы площади квартиры.\
#
# **rooms** - для этого столбца отфильтруем значения от 1 до 6 комнат.
#
# **ceiling_height** - отфилтруем эти значения в пределах от 2.5 до 3.5, так эти значения рекомендованы ГОСТ-ом
#
# **floors_total** - оставим значения меньше 40 этажей
#
# **living_area** - отфильтруем значения в этом столбце от 10 до 200.
#
# **floor** - столбец оставим без изменений, так как значения в пределах нормальных значений.
#
# **kitchen_area** - отфильтруем значения от 5 до 40 кв.м.
#
# **parks_nearest** - отфильтруем значения меньше 1200
#
# **balcony** , **airports_nearest**, **cityCenters_nearest**, **parks_around3000**,  **ponds_around3000**,**ponds_nearest**
#  оставим без фильтрации эти столбцы так как значения в них в пределах нормы.
#
# **days_exposition** - оставим в этом столбце значения, в которых значения меньше 1000 дней.

# %%
good_data = data.query(
    " total_images < 30"
    " and last_price <= last_price.median() * 3" 
    " and total_area >= 10 and total_area <= 150" 
    " and rooms >= 1 and rooms <= 6" 
    " and ceiling_height >= 2.5 and ceiling_height <= 3.5" 
    " and living_area >= 10 and living_area <= 200" 
    " and kitchen_area >= 5 and kitchen_area <= 30"
    " and parks_nearest < 1200 "
    " and days_exposition < 1000"
    " and floors_total < 40"
).reset_index(drop=True)

# %%
good_data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3            10     2890000        30.4           2018-09-10      1
# 4             6     3700000        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 0            2.70            16         51.0      8   False      False
# 1            2.65            11         18.6      1   False      False
# 2            2.65             5         34.3      4   False      False
# 3            2.65            12         14.4      5   False      False
# 4            2.65            26         10.6      6   False      False
#
#    kitchen_area  balcony                    locality_name  airports_nearest  \
# 0          25.0        1                  Санкт-Петербург             18863
# 1          11.0        2                   посёлок Шушары             12817
# 2           8.3        0                  Санкт-Петербург             21741
# 3           9.1        1  посёлок городского типа Янино-1             26726
# 4          14.4        1                посёлок Парголово             52996
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0                16028                 1            482                 2
# 1                18603                 0            455                 0
# 2                13933                 1             90                 2
# 3                13098                 0            455                 1
# 4                19143                 0            455                 0
#
#    ponds_nearest  days_exposition
# 0            755               95
# 1            502               81
# 2            574              558
# 3            502               55
# 4            502              155

# %%
good_data.shape
# Out:
# (21104, 21)

# %%
good_data.hist(bins=12, figsize=(12,12))
# Out:
# array([[<Axes: title={'center': 'total_images'}>,
#         <Axes: title={'center': 'last_price'}>,
#         <Axes: title={'center': 'total_area'}>,
#         <Axes: title={'center': 'first_day_exposition'}>],
#        [<Axes: title={'center': 'rooms'}>,
#         <Axes: title={'center': 'ceiling_height'}>,
#         <Axes: title={'center': 'floors_total'}>,
#         <Axes: title={'center': 'living_area'}>],
#        [<Axes: title={'center': 'floor'}>,
#         <Axes: title={'center': 'kitchen_area'}>,
#         <Axes: title={'center': 'balcony'}>,
#         <Axes: title={'center': 'airports_nearest'}>],
#        [<Axes: title={'center': 'cityCenters_nearest'}>,
#         <Axes: title={'center': 'parks_around3000'}>,
#         <Axes: title={'center': 'parks_nearest'}>,
#         <Axes: title={'center': 'ponds_around3000'}>],
#        [<Axes: title={'center': 'ponds_nearest'}>,
#         <Axes: title={'center': 'days_exposition'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
good_data.parks_nearest.value_counts()
# Out:
# 455    14586
# 441       41
# 392       30
# 456       29
# 458       28
#        ...
# 929        1
# 932        1
# 861        1
# 62         1
# 913        1
# Name: parks_nearest, Length: 890, dtype: int64

# %%
good_data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  21104.000000  2.110400e+04  21104.000000  21104.000000    21104.000000
# mean       9.740807  5.007772e+06     54.253551      1.969011        2.669741
# std        5.542691  2.474235e+06     19.647009      0.908080        0.159333
# min        0.000000  4.300000e+05     12.000000      1.000000        2.500000
# 25%        6.000000  3.350000e+06     39.500000      1.000000        2.600000
# 50%        9.000000  4.500000e+06     50.000000      2.000000        2.650000
# 75%       14.000000  6.140000e+06     64.800000      3.000000        2.700000
# max       29.000000  1.395000e+07    150.000000      6.000000        3.500000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  21104.000000  21104.000000  21104.000000  21104.000000  21104.000000
# mean      10.759050     31.080757      5.891442      9.614823      1.070555
# std        6.592339     13.413657      4.891159      3.490705      0.760961
# min        1.000000     10.000000      1.000000      5.000000      0.000000
# 25%        5.000000     18.875000      2.000000      7.100000      1.000000
# 50%        9.000000     30.000000      4.000000      9.100000      1.000000
# 75%       16.000000     39.000000      8.000000     11.000000      1.000000
# max       36.000000    128.000000     33.000000     30.000000      5.000000
#
#        airports_nearest  cityCenters_nearest  parks_around3000  parks_nearest  \
# count      21104.000000         21104.000000      21104.000000   21104.000000
# mean       28426.790040         14428.046579          0.417077     452.640874
# std        11242.220962          7367.177922          0.707421     123.827328
# min            0.000000           287.000000          0.000000       1.000000
# 25%        20906.000000         11703.000000          0.000000     455.000000
# 50%        26726.000000         13098.000000          0.000000     455.000000
# 75%        34668.500000         15519.000000          1.000000     455.000000
# max        84853.000000         65952.000000          3.000000    1199.000000
#
#        ponds_around3000  ponds_nearest  days_exposition
# count      21104.000000   21104.000000     21104.000000
# mean           0.773976     513.997346       154.257534
# std            0.777530     165.875551       173.195349
# min            0.000000      13.000000         1.000000
# 25%            0.000000     502.000000        45.000000
# 50%            1.000000     502.000000        95.000000
# 75%            1.000000     502.000000       187.000000
# max            3.000000    1344.000000       999.000000

# %%
good_data.cityCenters_nearest.value_counts()
# Out:
# 13098    5278
# 8460       35
# 20802      29
# 17369      24
# 20444      23
#          ...
# 5007        1
# 5180        1
# 5095        1
# 12224       1
# 6263        1
# Name: cityCenters_nearest, Length: 6971, dtype: int64

# %%
good_data.airports_nearest.value_counts()
# Out:
# 26726    5296
# 37434      35
# 21928      28
# 44870      27
# 47303      23
#          ...
# 30464       1
# 13760       1
# 23338       1
# 16282       1
# 20151       1
# Name: airports_nearest, Length: 7549, dtype: int64

# %%
good_data.parks_nearest.value_counts()
# Out:
# 455    14586
# 441       41
# 392       30
# 456       29
# 458       28
#        ...
# 929        1
# 932        1
# 861        1
# 62         1
# 913        1
# Name: parks_nearest, Length: 890, dtype: int64

# %%
good_data.ponds_nearest.value_counts()
# Out:
# 502     13589
# 427        44
# 433        37
# 454        31
# 400        29
#         ...
# 1017        1
# 1313        1
# 1074        1
# 508         1
# 827         1
# Name: ponds_nearest, Length: 1074, dtype: int64

# %% [markdown]
# Значения для **cityCenters_nearest** == 13098  **airports_nearest** == 26726  **parks_nearest** == 455 \ **ponds_nearest** == 502, явно выбиваются из общих распрделений, так как содержат большое число строк с такими значениями, вероятнее всего это может быть ошибочные значения из неправильной работы программы или же значения по умолчанию в случае если пользователь оставил незаполненным поле для соотвествующего столбца.

# %% [markdown]
# # Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
#  посчитано и добавлено в таблицу: цена одного квадратного метра\
#  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)\
#  посчитано и добавлено в таблицу: месяц публикации объявления\
#  посчитано и добавлено в таблицу: год публикации объявления\
#  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)\
#  посчитано и добавлено в таблицу: расстояние в км до центра города

# %%
good_data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3            10     2890000        30.4           2018-09-10      1
# 4             6     3700000        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 0            2.70            16         51.0      8   False      False
# 1            2.65            11         18.6      1   False      False
# 2            2.65             5         34.3      4   False      False
# 3            2.65            12         14.4      5   False      False
# 4            2.65            26         10.6      6   False      False
#
#    kitchen_area  balcony                    locality_name  airports_nearest  \
# 0          25.0        1                  Санкт-Петербург             18863
# 1          11.0        2                   посёлок Шушары             12817
# 2           8.3        0                  Санкт-Петербург             21741
# 3           9.1        1  посёлок городского типа Янино-1             26726
# 4          14.4        1                посёлок Парголово             52996
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0                16028                 1            482                 2
# 1                18603                 0            455                 0
# 2                13933                 1             90                 2
# 3                13098                 0            455                 1
# 4                19143                 0            455                 0
#
#    ponds_nearest  days_exposition
# 0            755               95
# 1            502               81
# 2            574              558
# 3            502               55
# 4            502              155

# %%
good_data['price_per_sq_m'] = (good_data['last_price'] / good_data['total_area']).round().astype('int')

column_name = 'price_per_sq_m'
column_values = good_data.pop(column_name)  # Удаляем столбец из конца и сохраняем его значения
good_data.insert(3, column_name, column_values) 

good_data.head()
# Out:
#    total_images  last_price  total_area  price_per_sq_m first_day_exposition  \
# 0            20    13000000       108.0          120370           2019-03-07
# 1             7     3350000        40.4           82921           2018-12-04
# 2            10     5196000        56.0           92786           2015-08-20
# 3            10     2890000        30.4           95066           2018-09-10
# 4             6     3700000        37.3           99196           2017-11-02
#
#    rooms  ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 0      3            2.70            16         51.0      8   False      False
# 1      1            2.65            11         18.6      1   False      False
# 2      2            2.65             5         34.3      4   False      False
# 3      1            2.65            12         14.4      5   False      False
# 4      1            2.65            26         10.6      6   False      False
#
#    kitchen_area  balcony                    locality_name  airports_nearest  \
# 0          25.0        1                  Санкт-Петербург             18863
# 1          11.0        2                   посёлок Шушары             12817
# 2           8.3        0                  Санкт-Петербург             21741
# 3           9.1        1  посёлок городского типа Янино-1             26726
# 4          14.4        1                посёлок Парголово             52996
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0                16028                 1            482                 2
# 1                18603                 0            455                 0
# 2                13933                 1             90                 2
# 3                13098                 0            455                 1
# 4                19143                 0            455                 0
#
#    ponds_nearest  days_exposition
# 0            755               95
# 1            502               81
# 2            574              558
# 3            502               55
# 4            502              155

# %%
day_of_week_mapping = {
    0: 'Понедельник',
    1: 'Вторник',
    2: 'Среда',
    3: 'Четверг',
    4: 'Пятница',
    5: 'Суббота',
    6: 'Воскресенье'
}

good_data['day_of_week'] = good_data['first_day_exposition'].dt.dayofweek.map(day_of_week_mapping)

column_name = 'day_of_week'
column_values = good_data.pop(column_name)
good_data.insert(5,column_name, column_values)
good_data.head()
# Out:
#    total_images  last_price  total_area  price_per_sq_m first_day_exposition  \
# 0            20    13000000       108.0          120370           2019-03-07
# 1             7     3350000        40.4           82921           2018-12-04
# 2            10     5196000        56.0           92786           2015-08-20
# 3            10     2890000        30.4           95066           2018-09-10
# 4             6     3700000        37.3           99196           2017-11-02
#
#    day_of_week  rooms  ceiling_height  floors_total  living_area  floor  \
# 0      Четверг      3            2.70            16         51.0      8
# 1      Вторник      1            2.65            11         18.6      1
# 2      Четверг      2            2.65             5         34.3      4
# 3  Понедельник      1            2.65            12         14.4      5
# 4      Четверг      1            2.65            26         10.6      6
#
#    studio  open_plan  kitchen_area  balcony                    locality_name  \
# 0   False      False          25.0        1                  Санкт-Петербург
# 1   False      False          11.0        2                   посёлок Шушары
# 2   False      False           8.3        0                  Санкт-Петербург
# 3   False      False           9.1        1  посёлок городского типа Янино-1
# 4   False      False          14.4        1                посёлок Парголово
#
#    airports_nearest  cityCenters_nearest  parks_around3000  parks_nearest  \
# 0             18863                16028                 1            482
# 1             12817                18603                 0            455
# 2             21741                13933                 1             90
# 3             26726                13098                 0            455
# 4             52996                19143                 0            455
#
#    ponds_around3000  ponds_nearest  days_exposition
# 0                 2            755               95
# 1                 0            502               81
# 2                 2            574              558
# 3                 1            502               55
# 4                 0            502              155

# %%
good_data.loc[:, 'first_day_exposition'].dt.month
# Out:
# 0         3
# 1        12
# 2         8
# 3         9
# 4        11
#          ..
# 21099     8
# 21100     1
# 21101     2
# 21102     3
# 21103     7
# Name: first_day_exposition, Length: 21104, dtype: int64

# %%
month_names = {
    1: 'Январь',
    2: 'Февраль',
    3: 'Март',
    4: 'Апрель',
    5: 'Май',
    6: 'Июнь',
    7: 'Июль',
    8: 'Август',
    9: 'Сентябрь',
    10: 'Октябрь',
    11: 'Ноябрь',
    12: 'Декабрь'
}

good_data['month'] = good_data['first_day_exposition'].dt.month.map(month_names)

column_name = 'month'
column_values = good_data.pop(column_name)
good_data.insert(6,column_name, column_values)
good_data.head()
# Out:
#    total_images  last_price  total_area  price_per_sq_m first_day_exposition  \
# 0            20    13000000       108.0          120370           2019-03-07
# 1             7     3350000        40.4           82921           2018-12-04
# 2            10     5196000        56.0           92786           2015-08-20
# 3            10     2890000        30.4           95066           2018-09-10
# 4             6     3700000        37.3           99196           2017-11-02
#
#    day_of_week     month  rooms  ceiling_height  floors_total  living_area  \
# 0      Четверг      Март      3            2.70            16         51.0
# 1      Вторник   Декабрь      1            2.65            11         18.6
# 2      Четверг    Август      2            2.65             5         34.3
# 3  Понедельник  Сентябрь      1            2.65            12         14.4
# 4      Четверг    Ноябрь      1            2.65            26         10.6
#
#    floor  studio  open_plan  kitchen_area  balcony  \
# 0      8   False      False          25.0        1
# 1      1   False      False          11.0        2
# 2      4   False      False           8.3        0
# 3      5   False      False           9.1        1
# 4      6   False      False          14.4        1
#
#                      locality_name  airports_nearest  cityCenters_nearest  \
# 0                  Санкт-Петербург             18863                16028
# 1                   посёлок Шушары             12817                18603
# 2                  Санкт-Петербург             21741                13933
# 3  посёлок городского типа Янино-1             26726                13098
# 4                посёлок Парголово             52996                19143
#
#    parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 0                 1            482                 2            755
# 1                 0            455                 0            502
# 2                 1             90                 2            574
# 3                 0            455                 1            502
# 4                 0            455                 0            502
#
#    days_exposition
# 0               95
# 1               81
# 2              558
# 3               55
# 4              155

# %%
good_data['year'] = good_data['first_day_exposition'].dt.year

column_name = 'year'
column_values = good_data.pop(column_name)
good_data.insert(7,column_name, column_values)
good_data.head()
# Out:
#    total_images  last_price  total_area  price_per_sq_m first_day_exposition  \
# 0            20    13000000       108.0          120370           2019-03-07
# 1             7     3350000        40.4           82921           2018-12-04
# 2            10     5196000        56.0           92786           2015-08-20
# 3            10     2890000        30.4           95066           2018-09-10
# 4             6     3700000        37.3           99196           2017-11-02
#
#    day_of_week     month  year  rooms  ceiling_height  floors_total  \
# 0      Четверг      Март  2019      3            2.70            16
# 1      Вторник   Декабрь  2018      1            2.65            11
# 2      Четверг    Август  2015      2            2.65             5
# 3  Понедельник  Сентябрь  2018      1            2.65            12
# 4      Четверг    Ноябрь  2017      1            2.65            26
#
#    living_area  floor  studio  open_plan  kitchen_area  balcony  \
# 0         51.0      8   False      False          25.0        1
# 1         18.6      1   False      False          11.0        2
# 2         34.3      4   False      False           8.3        0
# 3         14.4      5   False      False           9.1        1
# 4         10.6      6   False      False          14.4        1
#
#                      locality_name  airports_nearest  cityCenters_nearest  \
# 0                  Санкт-Петербург             18863                16028
# 1                   посёлок Шушары             12817                18603
# 2                  Санкт-Петербург             21741                13933
# 3  посёлок городского типа Янино-1             26726                13098
# 4                посёлок Парголово             52996                19143
#
#    parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 0                 1            482                 2            755
# 1                 0            455                 0            502
# 2                 1             90                 2            574
# 3                 0            455                 1            502
# 4                 0            455                 0            502
#
#    days_exposition
# 0               95
# 1               81
# 2              558
# 3               55
# 4              155

# %%
def categorize_floor(row):

    floor = row['floor']
    floor_total = row['floors_total']
    
    if floor == 1:
        return 'первый'
    
    if floor == floor_total:
        return 'последний'
    
    return 'другой'

good_data['floor_type'] = good_data.apply(categorize_floor,axis=1)
column_name='floor_type'
column_values = good_data.pop(column_name)
good_data.insert(13,column_name, column_values)

# %%
good_data['last_price_millions'] = good_data['last_price'] / 1000000

# %%
good_data.head()
# Out:
#    total_images  last_price  total_area  price_per_sq_m first_day_exposition  \
# 0            20    13000000       108.0          120370           2019-03-07
# 1             7     3350000        40.4           82921           2018-12-04
# 2            10     5196000        56.0           92786           2015-08-20
# 3            10     2890000        30.4           95066           2018-09-10
# 4             6     3700000        37.3           99196           2017-11-02
#
#    day_of_week     month  year  rooms  ceiling_height  floors_total  \
# 0      Четверг      Март  2019      3            2.70            16
# 1      Вторник   Декабрь  2018      1            2.65            11
# 2      Четверг    Август  2015      2            2.65             5
# 3  Понедельник  Сентябрь  2018      1            2.65            12
# 4      Четверг    Ноябрь  2017      1            2.65            26
#
#    living_area  floor floor_type  studio  open_plan  kitchen_area  balcony  \
# 0         51.0      8     другой   False      False          25.0        1
# 1         18.6      1     первый   False      False          11.0        2
# 2         34.3      4     другой   False      False           8.3        0
# 3         14.4      5     другой   False      False           9.1        1
# 4         10.6      6     другой   False      False          14.4        1
#
#                      locality_name  airports_nearest  cityCenters_nearest  \
# 0                  Санкт-Петербург             18863                16028
# 1                   посёлок Шушары             12817                18603
# 2                  Санкт-Петербург             21741                13933
# 3  посёлок городского типа Янино-1             26726                13098
# 4                посёлок Парголово             52996                19143
#
#    parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 0                 1            482                 2            755
# 1                 0            455                 0            502
# 2                 1             90                 2            574
# 3                 0            455                 1            502
# 4                 0            455                 0            502
#
#    days_exposition  last_price_millions
# 0               95               13.000
# 1               81                3.350
# 2              558                5.196
# 3               55                2.890
# 4              155                3.700

# %%
good_data[good_data['floor_type'] == 'последний']
# Out:
#        total_images  last_price  total_area  price_per_sq_m  \
# 10               10     3890000        54.0           72037
# 11               20     3550000        42.8           82944
# 20               11     2950000        32.0           92188
# 32               13     3790000        45.0           84222
# 38               13     9330000        48.0          194375
# ...             ...         ...         ...             ...
# 21049             3     3100000        30.0          103333
# 21052             7     4990000        62.5           79840
# 21056            14    10100000        78.0          129487
# 21068             1     2950000        53.6           55037
# 21091            15     2490000        31.0           80323
#
#       first_day_exposition day_of_week    month  year  rooms  ceiling_height  \
# 10              2016-06-30     Четверг     Июнь  2016      2            2.65
# 11              2017-07-01     Суббота     Июль  2017      2            2.56
# 20              2016-10-29     Суббота  Октябрь  2016      1            2.60
# 32              2017-01-25       Среда   Январь  2017      2            2.65
# 38              2017-01-10     Вторник   Январь  2017      2            3.00
# ...                    ...         ...      ...   ...    ...             ...
# 21049           2018-03-28       Среда     Март  2018      1            2.50
# 21052           2018-04-26     Четверг   Апрель  2018      2            2.70
# 21056           2017-05-12     Пятница      Май  2017      3            3.27
# 21068           2018-02-01     Четверг  Февраль  2018      2            2.75
# 21091           2019-01-24     Четверг   Январь  2019      1            2.50
#
#        floors_total  living_area  floor floor_type  studio  open_plan  \
# 10                5         30.0      5  последний   False      False
# 11                5         27.0      5  последний   False      False
# 20                9         17.7      9  последний   False      False
# 32                9         27.0      9  последний   False      False
# 38                4         28.0      4  последний   False      False
# ...             ...          ...    ...        ...     ...        ...
# 21049             5         17.0      5  последний   False      False
# 21052             4         32.3      4  последний   False      False
# 21056             5         48.6      5  последний   False      False
# 21068             3         32.0      3  последний   False      False
# 21091             5         17.3      5  последний   False      False
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 10              9.0        0        Сертолово             26726
# 11              5.2        1         Петергоф             37868
# 20              6.1        1  Санкт-Петербург             15414
# 32              6.3        2  Санкт-Петербург             49574
# 38              7.5        1  Санкт-Петербург             15016
# ...             ...      ...              ...               ...
# 21049           5.0        1          Колпино             24056
# 21052          12.1        1  Санкт-Петербург             20141
# 21056           8.2        1  Санкт-Петербург             20933
# 21068           5.8        1     Красное Село             38293
# 21091           5.6        1        Ломоносов             48393
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 10                   13098                 0            455                 1
# 11                   33058                 1            294                 3
# 20                   14211                 2            517                 1
# 32                   16461                 1            459                 0
# 38                   10822                 0            455                 1
# ...                    ...               ...            ...               ...
# 21049                29843                 0            455                 0
# 21052                 4415                 1            560                 1
# 21056                 1113                 1            621                 2
# 21068                41718                 0            455                 0
# 21091                51818                 0            455                 0
#
#        ponds_nearest  days_exposition  last_price_millions
# 10               502               90                 3.89
# 11               298              366                 3.55
# 20               190              615                 2.95
# 32               502              139                 3.79
# 38               492              763                 9.33
# ...              ...              ...                  ...
# 21049            502               10                 3.10
# 21052            171              166                 4.99
# 21056            117              621                10.10
# 21068            502               35                 2.95
# 21091            502               95                 2.49
#
# [2905 rows x 27 columns]

# %%
good_data[good_data['floor_type'] == 'первый']
# Out:
#        total_images  last_price  total_area  price_per_sq_m  \
# 1                 7     3350000        40.4           82921
# 12                1     4400000        36.0          122222
# 14               11     6700000        82.0           81707
# 21                8     6500000        97.2           66872
# 25                8     4170000        44.0           94773
# ...             ...         ...         ...             ...
# 21073            11     4250000        47.0           90426
# 21081             9     3100000        23.0          134783
# 21087            14     5000000        59.0           84746
# 21101            18     2500000        56.7           44092
# 21103             4     1350000        32.3           41796
#
#       first_day_exposition  day_of_week    month  year  rooms  ceiling_height  \
# 1               2018-12-04      Вторник  Декабрь  2018      1            2.65
# 12              2016-06-23      Четверг     Июнь  2016      1            2.65
# 14              2017-11-23      Четверг   Ноябрь  2017      3            3.05
# 21              2015-10-31      Суббота  Октябрь  2015      2            2.65
# 25              2017-12-13        Среда  Декабрь  2017      1            2.90
# ...                    ...          ...      ...   ...    ...             ...
# 21073           2016-05-20      Пятница      Май  2016      1            2.65
# 21081           2018-03-19  Понедельник     Март  2018      1            2.80
# 21087           2019-04-04      Четверг   Апрель  2019      3            2.50
# 21101           2018-02-11  Воскресенье  Февраль  2018      2            2.65
# 21103           2017-07-21      Пятница     Июль  2017      1            2.50
#
#        floors_total  living_area  floor floor_type  studio  open_plan  \
# 1                11         18.6      1     первый   False      False
# 12                6         17.0      1     первый   False      False
# 14                5         55.6      1     первый   False      False
# 21                3         46.5      1     первый   False      False
# 25                6         20.8      1     первый   False      False
# ...             ...          ...    ...        ...     ...        ...
# 21073             6         18.2      1     первый   False      False
# 21081             9         12.6      1     первый   False      False
# 21087             5         52.0      1     первый   False      False
# 21101             3         29.7      1     первый   False      False
# 21103             5         12.3      1     первый   False      False
#
#        kitchen_area  balcony        locality_name  airports_nearest  \
# 1              11.0        2       посёлок Шушары             12817
# 12              8.0        0               Пушкин             20782
# 14              9.0        1      Санкт-Петербург             22108
# 21             19.6        0      Санкт-Петербург             20052
# 25             11.7        1               Пушкин             18557
# ...             ...      ...                  ...               ...
# 21073          14.6        0      Санкт-Петербург             20503
# 21081           5.0        2      Санкт-Петербург             11813
# 21087           7.0        1      Санкт-Петербург             26835
# 21101           9.1        1     село Рождествено             26726
# 21103           9.0        1  посёлок Новый Учхоз             26726
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 1                    18603                 0            455                 0
# 12                   30759                 0            455                 1
# 14                   10698                 3            420                 0
# 21                    2336                 3            411                 3
# 25                   30710                 0            455                 1
# ...                    ...               ...            ...               ...
# 21073                 4946                 2            624                 1
# 21081                11881                 1            262                 1
# 21087                11878                 0            455                 0
# 21101                13098                 0            455                 1
# 21103                13098                 0            455                 1
#
#        ponds_nearest  days_exposition  last_price_millions
# 1                502               81                 3.35
# 12                96              203                 4.40
# 14               502              397                 6.70
# 21               124              265                 6.50
# 25               118               74                 4.17
# ...              ...              ...                  ...
# 21073            519              131                 4.25
# 21081            442               41                 3.10
# 21087            502               95                 5.00
# 21101            502               95                 2.50
# 21103            502               95                 1.35
#
# [2705 rows x 27 columns]

# %%
good_data['to_center_km'] = good_data['cityCenters_nearest'] / 1000

# %%
good_data.head()
# Out:
#    total_images  last_price  total_area  price_per_sq_m first_day_exposition  \
# 0            20    13000000       108.0          120370           2019-03-07
# 1             7     3350000        40.4           82921           2018-12-04
# 2            10     5196000        56.0           92786           2015-08-20
# 3            10     2890000        30.4           95066           2018-09-10
# 4             6     3700000        37.3           99196           2017-11-02
#
#    day_of_week     month  year  rooms  ceiling_height  floors_total  \
# 0      Четверг      Март  2019      3            2.70            16
# 1      Вторник   Декабрь  2018      1            2.65            11
# 2      Четверг    Август  2015      2            2.65             5
# 3  Понедельник  Сентябрь  2018      1            2.65            12
# 4      Четверг    Ноябрь  2017      1            2.65            26
#
#    living_area  floor floor_type  studio  open_plan  kitchen_area  balcony  \
# 0         51.0      8     другой   False      False          25.0        1
# 1         18.6      1     первый   False      False          11.0        2
# 2         34.3      4     другой   False      False           8.3        0
# 3         14.4      5     другой   False      False           9.1        1
# 4         10.6      6     другой   False      False          14.4        1
#
#                      locality_name  airports_nearest  cityCenters_nearest  \
# 0                  Санкт-Петербург             18863                16028
# 1                   посёлок Шушары             12817                18603
# 2                  Санкт-Петербург             21741                13933
# 3  посёлок городского типа Янино-1             26726                13098
# 4                посёлок Парголово             52996                19143
#
#    parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 0                 1            482                 2            755
# 1                 0            455                 0            502
# 2                 1             90                 2            574
# 3                 0            455                 1            502
# 4                 0            455                 0            502
#
#    days_exposition  last_price_millions  to_center_km
# 0               95               13.000        16.028
# 1               81                3.350        18.603
# 2              558                5.196        13.933
# 3               55                2.890        13.098
# 4              155                3.700        19.143

# %% [markdown]
# Добавлены следующие столбцы:
#
# **price_per_sq_m** - стоимость одного квадратного метра квартиры\
# **day_of_week** - день недели размещения объявления\
# **month** - месяц размещения объявления\
# **year** - год размещения объявления\
# **to_center_km** - расстояние до центра города в км
# **last_price_millions** - цена объекта в миллионах

# %% [markdown]
# #  Исследовательский анализ данных

# %% [markdown]
#  изучены и описаны следующие параметры:\
#         - общая площадь;\
#         - жилая площадь;\
#         - площадь кухни;\
#         - цена объекта;\
#         - количество комнат;\
#         - высота потолков;\
#         - этаж квартиры;\
#         - тип этажа квартиры («первый», «последний», «другой»);\
#         - общее количество этажей в доме;\
#         - расстояние до центра города в метрах;\
#         - расстояние до ближайшего аэропорта;\
#         - расстояние до ближайшего парка;\
#         - день и месяц публикации объявления\
#  построены гистограммы для каждого параметра\

# %%
good_data.describe()
# Out:
#        total_images    last_price    total_area  price_per_sq_m          year  \
# count  21104.000000  2.110400e+04  21104.000000    21104.000000  21104.000000
# mean       9.740807  5.007772e+06     54.253551    92545.739291   2017.408785
# std        5.542691  2.474235e+06     19.647009    30193.777186      1.000223
# min        0.000000  4.300000e+05     12.000000     7963.000000   2014.000000
# 25%        6.000000  3.350000e+06     39.500000    74948.500000   2017.000000
# 50%        9.000000  4.500000e+06     50.000000    92874.000000   2017.000000
# 75%       14.000000  6.140000e+06     64.800000   109756.000000   2018.000000
# max       29.000000  1.395000e+07    150.000000   387097.000000   2019.000000
#
#               rooms  ceiling_height  floors_total   living_area         floor  \
# count  21104.000000    21104.000000  21104.000000  21104.000000  21104.000000
# mean       1.969011        2.669741     10.759050     31.080757      5.891442
# std        0.908080        0.159333      6.592339     13.413657      4.891159
# min        1.000000        2.500000      1.000000     10.000000      1.000000
# 25%        1.000000        2.600000      5.000000     18.875000      2.000000
# 50%        2.000000        2.650000      9.000000     30.000000      4.000000
# 75%        3.000000        2.700000     16.000000     39.000000      8.000000
# max        6.000000        3.500000     36.000000    128.000000     33.000000
#
#        kitchen_area       balcony  airports_nearest  cityCenters_nearest  \
# count  21104.000000  21104.000000      21104.000000         21104.000000
# mean       9.614823      1.070555      28426.790040         14428.046579
# std        3.490705      0.760961      11242.220962          7367.177922
# min        5.000000      0.000000          0.000000           287.000000
# 25%        7.100000      1.000000      20906.000000         11703.000000
# 50%        9.100000      1.000000      26726.000000         13098.000000
# 75%       11.000000      1.000000      34668.500000         15519.000000
# max       30.000000      5.000000      84853.000000         65952.000000
#
#        parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# count      21104.000000   21104.000000      21104.000000   21104.000000
# mean           0.417077     452.640874          0.773976     513.997346
# std            0.707421     123.827328          0.777530     165.875551
# min            0.000000       1.000000          0.000000      13.000000
# 25%            0.000000     455.000000          0.000000     502.000000
# 50%            0.000000     455.000000          1.000000     502.000000
# 75%            1.000000     455.000000          1.000000     502.000000
# max            3.000000    1199.000000          3.000000    1344.000000
#
#        days_exposition  last_price_millions  to_center_km
# count     21104.000000         21104.000000  21104.000000
# mean        154.257534             5.007772     14.428047
# std         173.195349             2.474235      7.367178
# min           1.000000             0.430000      0.287000
# 25%          45.000000             3.350000     11.703000
# 50%          95.000000             4.500000     13.098000
# 75%         187.000000             6.140000     15.519000
# max         999.000000            13.950000     65.952000

# %%
good_data.hist(bins=20,figsize=(20,20), column=['total_area', 
                                                'living_area',
                                               'kitchen_area',
                                               'last_price',
                                               'rooms',
                                               'ceiling_height',
                                               'floor',
                                               'floor_type',
                                               'floors_total',
                                               'cityCenters_nearest',
                                               'airports_nearest',
                                               'parks_nearest',
                                               'day_of_week',
                                               'month'])
# Out:
# array([[<Axes: title={'center': 'total_area'}>,
#         <Axes: title={'center': 'living_area'}>,
#         <Axes: title={'center': 'kitchen_area'}>],
#        [<Axes: title={'center': 'last_price'}>,
#         <Axes: title={'center': 'rooms'}>,
#         <Axes: title={'center': 'ceiling_height'}>],
#        [<Axes: title={'center': 'floor'}>,
#         <Axes: title={'center': 'floors_total'}>,
#         <Axes: title={'center': 'cityCenters_nearest'}>],
#        [<Axes: title={'center': 'airports_nearest'}>,
#         <Axes: title={'center': 'parks_nearest'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# - общая площадь - большая часть площадей распределена в пределах от 40 до 65 кв.м, но есть также квартиры с большой площадью(150 кв.м) и маленьнкие (20 -кв.м)
#
# - жилая площадь - большая часть площадей распределена в пределах от 19 до 39 кв.м.
#
# - площадь кухни - площадь кухни в основном распределена в пределах от 7 до 11 кв.м, то есть примерно площадь кухни равна (общая площадь - жилая площадь)
#
# - цена объекта - значения этого столбца распределены по нормальному закону, в среднем цена имеет значения от 3 до 6 миллионов, но также есть дорогие объекты ценой выше
#
# - количество комнат - самые распространенные объекты с 1-ой, 2-мя, и 3-мя комнатами, другие варианты встречаются реже.
#
# - высота потолков - самый распространенный вариант это 2.65 м - это высота потолков по ГОСТУ
#
# - этаж квартиры - распределение показывает, что в основном размещаются квартиры низких этажей , что говорит, о том преимещественно распространена средне этажная застройка (5 , 9 этажей в объекте)
#
# - тип этажа квартиры («первый», «последний», «другой») - больше всего квартир с типом этажа - Другой
#
# - общее количество этажей в доме - самые распространенные обьекты с 5 и 9 этажами
#
#
# Значения для **cityCenters_nearest** == 13098  **airports_nearest** == 26726  **parks_nearest** == 455 \ **ponds_nearest** == 502, явно выбиваются из общих распрделений, так как содержат большое число строк с такими значениями, вероятнее всего это может быть ошибочные значения из неправильной работы программы или же значения по умолчанию в случае если пользователь оставил незаполненным поле для соотвествующего столбца.

# %%
good_data['floor_type'].hist(bins=20)
# Out:
# <Axes: >

# %%
good_data['day_of_week'].hist(bins=7,figsize=(10,2))
# Out:
# <Axes: >

# %% [markdown]
# Гистограмма показывает, что реже всего обьявления публикуются в выходные дни. Так как в эти дни люди скорее всего уделяют больше времени отдыху.

# %%
good_data['month'].hist(bins=30,figsize=(10,2))
# Out:
# <Axes: >

# %% [markdown]
# Меньше всего объявлений размещатся в мае, январе и декабре. Вероятнее всего это связано с тем что в эти месяцы много праздников или длинных выходных и ,соответсвенно, люди уделяют больше времени отдыху нежели размещению объявлений.

# %% [markdown]
# Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
# Постройте гистограмму.
# Посчитайте среднее и медиану.
# В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"

# %%
good_data.days_exposition.hist(bins=50)
# Out:
# <Axes: >

# %%
good_data.days_exposition.describe()
# Out:
# count    21104.000000
# mean       154.257534
# std        173.195349
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        187.000000
# max        999.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# *Описание времени продажи*:\
# В среднем квартиры продаются за 154 дня. Медианное значение составляет 95 дней, что означает, что половина квартир продается быстрее этого срока, а другая половина — медленнее.
#
# *Быстрые и долгие продажи:*
#
# Продажи можно считать быстрыми, если время продажи составляет менее 45 дней, так как это значение находится в 25-м процентиле (нижний квартиль).
# Продажи можно считать необычно долгими, если время продажи превышает 187 дней, так как это значение находится в 75-м процентиле (верхний квартиль).
# Продажи со значениями между 45 и 187 днями считаются средними в этом контексте.

# %% [markdown]
# выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."\
#         - общей площади;\
#         - жилой площади;\
#         - площади кухни;\
#         - количество комнат;\
#         - типа этажа, на котором расположена квартира (первый, последний, другой);\
#         - даты размещения (день недели, месяц, год);

# %%
good_data_last_price = good_data[['last_price','last_price_millions','total_area','living_area','kitchen_area','rooms','floor_type','day_of_week','month','year']]
good_data_last_price.head()
# Out:
#    last_price  last_price_millions  total_area  living_area  kitchen_area  \
# 0    13000000               13.000       108.0         51.0          25.0
# 1     3350000                3.350        40.4         18.6          11.0
# 2     5196000                5.196        56.0         34.3           8.3
# 3     2890000                2.890        30.4         14.4           9.1
# 4     3700000                3.700        37.3         10.6          14.4
#
#    rooms floor_type  day_of_week     month  year
# 0      3     другой      Четверг      Март  2019
# 1      1     первый      Вторник   Декабрь  2018
# 2      2     другой      Четверг    Август  2015
# 3      1     другой  Понедельник  Сентябрь  2018
# 4      1     другой      Четверг    Ноябрь  2017

# %%
good_data_last_price.corr()['last_price_millions']
# Out:
# C:\Users\Иван\AppData\Local\Temp\ipykernel_22880\779955465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   good_data_last_price.corr()['last_price_millions']
# last_price             1.000000
# last_price_millions    1.000000
# total_area             0.728205
# living_area            0.586544
# kitchen_area           0.490171
# rooms                  0.470696
# year                   0.004402
# Name: last_price_millions, dtype: float64

# %% [markdown]
# Как можно заметить, цена объекта положительно коррелирует с общей площадью объекта, жилой площадью, площадью кухни и количеством комнат. И никак не коррелирует с годом размещения обьъекта.

# %%
columns_to_analyze = ['total_area', 'living_area', 'kitchen_area']

fig, axes = plt.subplots(nrows=1, ncols=len(columns_to_analyze), figsize=(15, 5))

for i, column in enumerate(columns_to_analyze):
    x = good_data_last_price[column]
    y = good_data_last_price['last_price']
    
    axes[i].scatter(x, y, alpha=0.5)
    axes[i].set_title(f'Зависимость цены от {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Цена')
    axes[i].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Коэффициент корреляции 0.728205 означает, что существует довольно сильная положительная линейная связь между общей площадью квартиры и её ценой. То есть, как правило, с увеличением общей площади квартиры цена также увеличивается. Это может быть объяснено тем, что квартиры с большей площадью обычно имеют больше места и удобств, что может повысить их стоимость.\
# Также наблюдается положительная корреляция между площадью жилой и кухонной части квартиры.

# %%
pivot_rooms = good_data.pivot_table(index='rooms', values='last_price_millions', aggfunc='mean')
pivot_rooms
# Out:
#        last_price_millions
# rooms
# 1                 3.746747
# 2                 5.080128
# 3                 6.325949
# 4                 7.473074
# 5                 9.064564
# 6                10.599474

# %%
pivot_rooms.plot(kind='bar', legend=None)
plt.xlabel('Кол-во комнат')
plt.ylabel('Средняя стоимость')
plt.title('Зависимость цены от кол-ва комнат')
plt.show()

# %% [markdown]
# Количество комнат влияет на цену объекта, а именно, чем больше комнат, тем выше средняя стоимость квартиры.

# %%
pivot_floor_type = good_data_last_price.pivot_table(index='floor_type', values='last_price_millions', aggfunc='mean')
pivot_floor_type
# Out:
#             last_price_millions
# floor_type
# другой                 5.219725
# первый                 4.205902
# последний              4.623974

# %%
pivot_floor_type.plot(kind='bar', legend=None)
plt.ylabel('Средняя стоимость')
plt.xlabel('Тип этажа')
plt.title('Зависимость цены от типа этажа')
# Out:
# Text(0.5, 1.0, 'Зависимость цены от типа этажа')

# %% [markdown]
# Как правило, объекты первых и последних этажей стоят дешевле, чем  объекты на другий этажах.

# %%
pivot_day_of_week = good_data_last_price.pivot_table(index='day_of_week', values='last_price_millions', aggfunc='mean')
pivot_day_of_week
# Out:
#              last_price_millions
# day_of_week
# Воскресенье             4.930526
# Вторник                 5.076395
# Понедельник             5.010994
# Пятница                 4.990594
# Среда                   5.051352
# Суббота                 4.885565
# Четверг                 5.001184

# %%
pivot_day_of_week.plot(kind='bar', legend=None)
plt.ylabel('Средняя стоимость')
plt.xlabel('День недели размещения объявления')
plt.title('Зависимость цены от дня недели')
# Out:
# Text(0.5, 1.0, 'Зависимость цены от дня недели')

# %% [markdown]
# День недели почти никак не влияет цену.

# %%
pivot_month = good_data_last_price.pivot_table(index='month', values='last_price_millions', aggfunc='mean')
pivot_month
# Out:
#           last_price_millions
# month
# Август               5.010977
# Апрель               5.104019
# Декабрь              5.008769
# Июль                 4.993017
# Июнь                 4.793105
# Май                  4.967559
# Март                 5.019098
# Ноябрь               5.078874
# Октябрь              4.960889
# Сентябрь             5.132249
# Февраль              4.965058
# Январь               4.999601

# %%
pivot_month.plot(kind='bar', legend=None)
plt.ylabel('Средняя стоимость')
plt.xlabel('Месяц размещения объявления')
plt.title('Зависимость цены от месяца')
# Out:
# Text(0.5, 1.0, 'Зависимость цены от месяца')

# %% [markdown]
# Месяц размещения почти никак не влияет на стоимость.

# %%
pivot_year = good_data_last_price.pivot_table(index='year', values='last_price_millions', aggfunc='mean')
pivot_year
# Out:
#       last_price_millions
# year
# 2014             6.509593
# 2015             5.336326
# 2016             4.987388
# 2017             4.930618
# 2018             4.938016
# 2019             5.309518

# %%
pivot_year.plot(kind='bar', legend=None)
plt.ylabel('Средняя стоимость')
plt.xlabel('Год размещения объявления')
plt.title('Зависимость цены от года размещения')
# Out:
# Text(0.5, 1.0, 'Зависимость цены от года размещения')

# %% [markdown]
# Как можно заметить, объявления размещенные в 2014 году имеют наибольшую среднюю стоимость.

# %% [markdown]
# Тем самым можно сделать вывод, что на цену больше всего влияет полная, жилая и площадь кухни и тип этажа , как правило, объекты с первого и последнего этажа стоят дороже.

# %% [markdown]
# выполнени задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце locality_name."

# %%
top_ten_locality = good_data.groupby('locality_name')['locality_name'].count().sort_values(ascending=False).head(10).index
top_ten_locality
# Out:
# Index(['Санкт-Петербург', 'посёлок Мурино', 'посёлок Шушары', 'Всеволожск',
#        'Пушкин', 'Колпино', 'посёлок Парголово', 'Гатчина', 'деревня Кудрово',
#        'Выборг'],
#       dtype='object', name='locality_name')

# %%
top_ten_list = []
for i in top_ten_locality:
    top_ten_list.append(i)
    
top_ten_list
# Out:
# ['Санкт-Петербург',
#  'посёлок Мурино',
#  'посёлок Шушары',
#  'Всеволожск',
#  'Пушкин',
#  'Колпино',
#  'посёлок Парголово',
#  'Гатчина',
#  'деревня Кудрово',
#  'Выборг']

# %%
good_data.pivot_table(index='locality_name', values='price_per_sq_m', aggfunc='mean')
# Out:
#                       price_per_sq_m
# locality_name
# Бокситогорск            17457.333333
# Волосово                40183.305556
# Волхов                  35099.407407
# Всеволожск              67137.314136
# Выборг                  58110.404444
# ...                              ...
# село Путилово           39921.500000
# село Рождествено        37733.000000
# село Русско-Высоцкое    54833.777778
# село Старая Ладога      34697.000000
# село Шум                33898.000000
#
# [318 rows x 1 columns]

# %%
top_ten_locality_data = good_data[good_data['locality_name'].isin(top_ten_locality)]
top_ten_locality_data.head(10)
# Out:
#     total_images  last_price  total_area  price_per_sq_m first_day_exposition  \
# 0             20    13000000      108.00          120370           2019-03-07
# 1              7     3350000       40.40           82921           2018-12-04
# 2             10     5196000       56.00           92786           2015-08-20
# 4              6     3700000       37.30           99196           2017-11-02
# 5              5     7915000       71.60          110545           2019-04-18
# 6             20     2900000       33.16           87455           2018-05-23
# 7             18     5400000       61.00           88525           2017-02-26
# 8              5     5050000       39.60          127525           2017-11-16
# 12             1     4400000       36.00          122222           2016-06-23
# 13            16     4650000       39.00          119231           2017-11-18
#
#     day_of_week    month  year  rooms  ceiling_height  floors_total  \
# 0       Четверг     Март  2019      3            2.70            16
# 1       Вторник  Декабрь  2018      1            2.65            11
# 2       Четверг   Август  2015      2            2.65             5
# 4       Четверг   Ноябрь  2017      1            2.65            26
# 5       Четверг   Апрель  2019      2            2.65            24
# 6         Среда      Май  2018      1            2.65            27
# 7   Воскресенье  Февраль  2017      3            2.50             9
# 8       Четверг   Ноябрь  2017      1            2.67            12
# 12      Четверг     Июнь  2016      1            2.65             6
# 13      Суббота   Ноябрь  2017      1            2.65            14
#
#     living_area  floor floor_type  studio  open_plan  kitchen_area  balcony  \
# 0         51.00      8     другой   False      False         25.00        1
# 1         18.60      1     первый   False      False         11.00        2
# 2         34.30      4     другой   False      False          8.30        0
# 4         10.60      6     другой   False      False         14.40        1
# 5         30.00     22     другой   False      False         18.90        2
# 6         15.43     26     другой   False      False          8.81        1
# 7         43.60      7     другой   False      False          6.50        2
# 8         20.30      3     другой   False      False          8.50        1
# 12        17.00      1     первый   False      False          8.00        0
# 13        20.50      5     другой   False      False          7.60        1
#
#         locality_name  airports_nearest  cityCenters_nearest  \
# 0     Санкт-Петербург             18863                16028
# 1      посёлок Шушары             12817                18603
# 2     Санкт-Петербург             21741                13933
# 4   посёлок Парголово             52996                19143
# 5     Санкт-Петербург             23982                11634
# 6      посёлок Мурино             26726                13098
# 7     Санкт-Петербург             50898                15008
# 8     Санкт-Петербург             38357                13878
# 12             Пушкин             20782                30759
# 13    Санкт-Петербург             12900                14259
#
#     parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 0                  1            482                 2            755
# 1                  0            455                 0            502
# 2                  1             90                 2            574
# 4                  0            455                 0            502
# 5                  0            455                 0            502
# 6                  0            455                 1            502
# 7                  0            455                 0            502
# 8                  1            310                 2            553
# 12                 0            455                 1             96
# 13                 1            590                 1            296
#
#     days_exposition  last_price_millions  to_center_km
# 0                95               13.000        16.028
# 1                81                3.350        18.603
# 2               558                5.196        13.933
# 4               155                3.700        19.143
# 5                95                7.915        11.634
# 6               189                2.900        13.098
# 7               289                5.400        15.008
# 8               137                5.050        13.878
# 12              203                4.400        30.759
# 13               19                4.650        14.259

# %%
top_ten_locality_data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'посёлок Парголово',
#        'посёлок Мурино', 'Пушкин', 'деревня Кудрово', 'Колпино',
#        'Гатчина', 'Выборг', 'Всеволожск'], dtype=object)

# %%
top_ten_locality_data.pivot_table(index='locality_name', values=['price_per_sq_m'], aggfunc='mean')\
    .sort_values(by='price_per_sq_m',ascending=False)
# Out:
#                    price_per_sq_m
# locality_name
# Санкт-Петербург     106123.964138
# Пушкин              100922.157100
# деревня Кудрово      92291.557971
# посёлок Парголово    90406.025000
# посёлок Мурино       85030.700772
# посёлок Шушары       78225.180328
# Колпино              75354.037152
# Гатчина              68842.608696
# Всеволожск           67137.314136
# Выборг               58110.404444
