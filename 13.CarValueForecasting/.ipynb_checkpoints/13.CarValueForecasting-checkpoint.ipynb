# %% [markdown]
# <span style="color:black;font-weight:700;font-size:32px">
#                Предсказание цены автомобиля
#
# </span>

# %% [markdown]
# <span style="color:black;font-weight:700;font-size:22px">
#               Описание проекта
# </span>
#
# Сервис по продаже автомобилей с пробегом «Не бит, не крашен» разрабатывает приложение, чтобы привлечь новых клиентов. В нём можно будет узнать рыночную стоимость своего автомобиля.\
# Постройте модель, которая умеет её определять. В вашем распоряжении данные о технических характеристиках, комплектации и ценах других автомобилей.
#
# Критерии, которые важны заказчику:
# - качество предсказания;
# - время обучения модели;
# - время предсказания модели.
#
#
#
# <span style="color:black;font-weight:700;font-size:18px">
#               Описание данных
# </span>
#
#
# Данные находятся в файле /datasets/autos.csv.
#
# Признаки
# - **DateCrawled** — дата скачивания анкеты из базы
# - **VehicleType** — тип автомобильного кузова
# - **RegistrationYear** — год регистрации автомобиля
# - **Gearbox** — тип коробки передач
# - **Power** — мощность (л. с.)
# - **Model** — модель автомобиля
# - **Kilometer** — пробег (км)
# - **RegistrationMonth** — месяц регистрации автомобиля
# - **FuelType** — тип топлива
# - **Brand** — марка автомобиля
# - **Repaired** — была машина в ремонте или нет
# - **DateCreated** — дата создания анкеты
# - **NumberOfPictures** — количество фотографий автомобиля
# - **PostalCode** — почтовый индекс владельца анкеты (пользователя)
# - **LastSeen** — дата последней активности пользователя
#
#
# **Целевой признак**
#   **Price — цена (евро)**

# %% [markdown]
# <span style="color:black;font-weight:700;font-size:22px">
#               План работы
#  </span>
#
# 1) Загрузка данных
#
# 2) Предобработка данных
#
# 3) Исследовательский анализ данных
#
# 4) Объединение датасетов
#
# 5) Корреляционный анализ
#
# 6) Построение пайплайнов моделей машинного обучения (KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression(), SVC().)
#
# 7) Анализ важности признаков.
#
# 8) Сегментация покупателей.
#
# 9) Общий вывод

# %% [markdown]
# # Загрузка данных

# %%
! pip install phik -q
! pip install catboost -q
! pip install lightgbm -q

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
from phik import phik_matrix
from phik.report import plot_correlation_matrix
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.linear_model import LinearRegression, Lasso, SGDRegressor, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import KNNImputer
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

# %%
try:
    data = pd.read_csv('/datasets/autos.csv', parse_dates=['DateCrawled', 'DateCreated','LastSeen'])

except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/autos.csv', parse_dates=['DateCrawled', 'DateCreated','LastSeen'])
    
data.head(10)
# Out:
#           DateCrawled  Price  VehicleType  RegistrationYear Gearbox  Power  \
# 0 2016-03-24 11:52:17    480          NaN              1993  manual      0
# 1 2016-03-24 10:58:45  18300        coupe              2011  manual    190
# 2 2016-03-14 12:52:21   9800          suv              2004    auto    163
# 3 2016-03-17 16:54:04   1500        small              2001  manual     75
# 4 2016-03-31 17:25:20   3600        small              2008  manual     69
# 5 2016-04-04 17:36:23    650        sedan              1995  manual    102
# 6 2016-04-01 20:48:51   2200  convertible              2004  manual    109
# 7 2016-03-21 18:54:38      0        sedan              1980  manual     50
# 8 2016-04-04 23:42:13  14500          bus              2014  manual    125
# 9 2016-03-17 10:53:50    999        small              1998  manual    101
#
#      Model  Kilometer  RegistrationMonth  FuelType       Brand Repaired  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  datetime64[ns]
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Kilometer          354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  Repaired           283215 non-null  object
#  12  DateCreated        354369 non-null  datetime64[ns]
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
# ...

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# Проведем предварительную предобработку данных,  в ходе которой обработаем пропуски, дубликаты(явные, неявные), выбросы

# %%
nan_df = pd.DataFrame(data.isnull().mean() * 100, columns=['nan_perc'])
nan_df
# Out:
#                     nan_perc
# DateCrawled         0.000000
# Price               0.000000
# VehicleType        10.579368
# RegistrationYear    0.000000
# Gearbox             5.596709
# Power               0.000000
# Model               5.560588
# Kilometer           0.000000
# RegistrationMonth   0.000000
# FuelType            9.282697
# Brand               0.000000
# Repaired           20.079070
# DateCreated         0.000000
# NumberOfPictures    0.000000
# PostalCode          0.000000
# LastSeen            0.000000

# %%
to_fill_cols = nan_df[nan_df['nan_perc'] > 0].index.to_list()
for col in to_fill_cols:
    data[col] = data[col].fillna(data[col].mode()[0])

# %%
data.isnull().mean() * 100
# Out:
# DateCrawled          0.0
# Price                0.0
# VehicleType          0.0
# RegistrationYear     0.0
# Gearbox              0.0
# Power                0.0
# Model                0.0
# Kilometer            0.0
# RegistrationMonth    0.0
# FuelType             0.0
# Brand                0.0
# Repaired             0.0
# DateCreated          0.0
# NumberOfPictures     0.0
# PostalCode           0.0
# LastSeen             0.0
# dtype: float64

# %% [markdown]
# Так как пропуски присутствовали в категориальных признаках, обработали их модой по столбцу

# %%
data.duplicated().sum()
# Out:
# 5

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Проверим признаки на неявные дубликаты

# %%
object_columns = data.select_dtypes(include='object').columns.to_list()

# %%
for col in object_columns:
    print(col)
    print(data[col].value_counts())
    print()
# Out:
# VehicleType
# sedan          128946
# small           79830
# wagon           65165
# bus             28775
# convertible     20203
# coupe           16161
# suv             11996
# other            3288
# Name: VehicleType, dtype: int64
#
# Gearbox
# manual    288081
# auto       66283
# Name: Gearbox, dtype: int64
#
# Model
# golf                  48937
# other                 24420
# 3er                   19761
# polo                  13066
# corsa                 12570
#                       ...
# i3                        8
# serie_3                   4
# rangerover                4
# range_rover_evoque        2
# serie_1                   2
# Name: Model, Length: 250, dtype: int64
#
# FuelType
# petrol      249244
# gasoline     98718
# lpg           5310
# cng            565
# hybrid         233
# other          204
# electric        90
# Name: FuelType, dtype: int64
#
# Brand
# volkswagen        77012
# opel              39931
# bmw               36914
# ...

# %% [markdown]
# Неявные дубликаты в датасет отсутствуют

# %%
num_cols = data.select_dtypes(include=['int64', 'float64']).columns.to_list()
num_cols
# Out:
# ['Price',
#  'RegistrationYear',
#  'Power',
#  'Kilometer',
#  'RegistrationMonth',
#  'NumberOfPictures',
#  'PostalCode']

# %%
data[num_cols].hist(bins=60, figsize=(12,8));
display(data.describe())
# Out:
#                Price  RegistrationYear          Power      Kilometer  \
# count  354364.000000     354364.000000  354364.000000  354364.000000
# mean     4416.655608       2004.234471     110.093723  128211.373051
# std      4514.159690         90.228593     189.851590   37905.136957
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354364.000000          354364.0  354364.000000
# mean            5.714641               0.0   50508.461698
# std             3.726433               0.0   25783.124276
# min             0.000000               0.0    1067.000000
# ...

# %% [markdown]
# Можно заметить, что в столбцах Price,Power, RegistratoinMonth минимальные значения равны 0, скорее всего такие значения являются скрытыми пропусками, поэтому в дальнейшем также обработаем их

# %%
num_plots = len(num_cols)
num_columns = 3
num_rows = -(-num_plots // num_columns)  

fig, axes = plt.subplots(num_rows, num_columns, figsize=(15, 5*num_rows))

for i, column in enumerate(num_cols):
    row = i // num_columns
    col = i % num_columns
    ax = axes[row, col]

    data.boxplot(column=column, ax=ax)
    ax.set_title(f'Boxplot for {column}')
    ax.set_ylabel('Values')
    ax.grid(False)

for i in range(num_plots, num_rows * num_columns):
    row = i // num_columns
    col = i % num_columns
    fig.delaxes(axes[row, col])

plt.tight_layout()
plt.show()

# %% [markdown]
# Обработаем выбросы на уровне 0,01 и 0.99 квантилей

# %%
def handle_outliers_all_columns(dataframe, low_quantile=None, high_quantile=None):
    """
    Параметры:
    - dataframe: pandas DataFrame, входной датасет
    - lower_bound: float, нижняя граница для обработки выбросов
    - upper_bound: float, верхняя граница для обработки выбросов 
    """
    df = dataframe.copy()

    numeric_columns = num_cols
    
    size_of_dataset_before_handling = df.shape[0]
    for column_name in numeric_columns:
        lower_bound = df[column_name].quantile(low_quantile)
        higher_bound = df[column_name].quantile(high_quantile)
        df = df[(df[column_name] >= lower_bound) & (df[column_name] <= higher_bound)]
        
        
    size_of_dataset_after_handling = df.shape[0]
    print(f"Процент удаленных значений {(1- (size_of_dataset_after_handling / size_of_dataset_before_handling)) * 100}")
    
    
    return df

# %%
data = handle_outliers_all_columns(dataframe=data, low_quantile=0.01, high_quantile=0.99)
# Out:
# Процент удаленных значений 4.825546613087106

# %%
data[num_cols].hist(bins=60, figsize=(12,8));
display(data.describe())
# Out:
#                Price  RegistrationYear          Power      Kilometer  \
# count  337264.000000     337264.000000  337264.000000  337264.000000
# mean     4203.730105       2003.371187     104.096880  129052.641254
# std      4220.718673          6.597841      58.602136   37098.575136
# min         0.000000       1980.000000       0.000000    5000.000000
# 25%      1000.000000       1999.000000      69.000000  125000.000000
# 50%      2600.000000       2003.000000     102.000000  150000.000000
# 75%      6000.000000       2008.000000     140.000000  150000.000000
# max     18800.000000       2018.000000     299.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      337264.000000          337264.0  337264.000000
# mean            5.725645               0.0   50457.629863
# std             3.726871               0.0   25070.372259
# min             0.000000               0.0    2692.000000
# ...

# %% [markdown]
# Обработка квантилями не убрала "нулевые значения" обработаем их вручную

# %%
data = data.query('Price > 100 and Power > 50 and RegistrationMonth > 0')

# %%
data[num_cols].hist(bins=60, figsize=(12,8));
display(data.describe())
# Out:
#                Price  RegistrationYear          Power      Kilometer  \
# count  264212.000000     264212.000000  264212.000000  264212.000000
# mean     4857.580776       2003.707110     120.471546  128640.409974
# std      4341.901324          6.114666      47.070554   36154.767582
# min       101.000000       1980.000000      51.000000    5000.000000
# 25%      1500.000000       1999.000000      82.000000  125000.000000
# 50%      3399.000000       2004.000000     115.000000  150000.000000
# 75%      6999.000000       2008.000000     150.000000  150000.000000
# max     18800.000000       2018.000000     299.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      264212.000000          264212.0  264212.000000
# mean            6.389305               0.0   51380.528916
# std             3.347404               0.0   25064.388265
# min             1.000000               0.0    2692.000000
# ...

# %% [markdown]
# Также можно заметить, что столбец NumberOfPictures содержит только нулевые значения, соответственно, он будет неинформативным для нас и его можно удалить

# %%
data = data.drop(columns=['NumberOfPictures'])

# %%
data.head()
# Out:
#           DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 1 2016-03-24 10:58:45  18300       coupe              2011  manual    190
# 2 2016-03-14 12:52:21   9800         suv              2004    auto    163
# 3 2016-03-17 16:54:04   1500       small              2001  manual     75
# 4 2016-03-31 17:25:20   3600       small              2008  manual     69
# 5 2016-04-04 17:36:23    650       sedan              1995  manual    102
#
#    Model  Kilometer  RegistrationMonth  FuelType       Brand Repaired  \
# 1   golf     125000                  5  gasoline        audi      yes
# 2  grand     125000                  8  gasoline        jeep       no
# 3   golf     150000                  6    petrol  volkswagen       no
# 4  fabia      90000                  7  gasoline       skoda       no
# 5    3er     150000                 10    petrol         bmw      yes
#
#   DateCreated  PostalCode            LastSeen
# 1  2016-03-24       66954 2016-04-07 01:46:50
# ...

# %% [markdown]
# Также удалим неинформативные для нас следующие признаки :\
# DateCrawled — дата скачивания анкеты из базы\
# LastSeen — дата последней активности пользователя\
# DateCreated — дата создания анкеты

# %%
data = data.drop(columns=['DateCrawled', 'LastSeen', 'DateCreated'])

# %%
data.head()
# Out:
#    Price VehicleType  RegistrationYear Gearbox  Power  Model  Kilometer  \
# 1  18300       coupe              2011  manual    190   golf     125000
# 2   9800         suv              2004    auto    163  grand     125000
# 3   1500       small              2001  manual     75   golf     150000
# 4   3600       small              2008  manual     69  fabia      90000
# 5    650       sedan              1995  manual    102    3er     150000
#
#    RegistrationMonth  FuelType       Brand Repaired  PostalCode
# 1                  5  gasoline        audi      yes       66954
# 2                  8  gasoline        jeep       no       90480
# 3                  6    petrol  volkswagen       no       91074
# 4                  7  gasoline       skoda       no       60437
# 5                 10    petrol         bmw      yes       33775

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264212 entries, 1 to 354368
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Price              264212 non-null  int64
#  1   VehicleType        264212 non-null  object
#  2   RegistrationYear   264212 non-null  int64
#  3   Gearbox            264212 non-null  object
#  4   Power              264212 non-null  int64
#  5   Model              264212 non-null  object
#  6   Kilometer          264212 non-null  int64
#  7   RegistrationMonth  264212 non-null  int64
#  8   FuelType           264212 non-null  object
#  9   Brand              264212 non-null  object
#  10  Repaired           264212 non-null  object
#  11  PostalCode         264212 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 26.2+ MB

# %% [markdown]
# <span style="color:black;font-weight:700;font-size:18px">
#        Вывод
# </span>
#
# В результате предобработки данных были обработаны пропуски, выбросы и дубликаты

# %% [markdown]
# # Исследовательский анализ данных

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

sns.histplot(data['Price'], kde=True, color='skyblue', bins=30)

median_price = data['Price'].median()
plt.axvline(x=median_price, color='r', linestyle=':', linewidth=2, label='Медиана цен')

plt.text(median_price, 30, f'Median: {median_price:.2f}', color='r', fontsize=12, ha='right')
plt.title('Распределение цен', fontsize=16)
plt.xlabel('Цена', fontsize=14)
plt.ylabel('Частота', fontsize=14)
plt.legend()

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# Проведем исследовательский анализ и посмотрим какие признаки больше всего влияют на целевой признак цены

# %%
data.pivot_table(index=['Brand'], 
                 values=['Price'], 
                 aggfunc=np.mean)\
    .sort_values(by='Price',ascending=False)\
    .plot(kind='bar', figsize=(12,6), color='skyblue', edgecolor='black')
plt.xlabel('Бренд')
plt.ylabel('Средняя цена')
plt.title('Средние цена автомобилей разных брендов')
# Out:
# Text(0.5, 1.0, 'Средние цена автомобилей разных брендов')

# %% [markdown]
# Самые дорогие машины брендов Porsche, Mini, Land Rover, Jeep, Audi, BMW

# %%
data.pivot_table(index=['Gearbox'], 
                 values=['Price'], 
                 aggfunc=np.mean)\
    .sort_values(by='Price',ascending=False)\
    .plot(kind='bar', figsize=(12,6), color='skyblue', edgecolor='black')
plt.xlabel('Бренд')
plt.ylabel('Средняя цена')
plt.title('Средние цена автомобилей c разными типами коробки передач')
# Out:
# Text(0.5, 1.0, 'Средние цена автомобилей c разными типами коробки передач')

# %% [markdown]
# Как правило дороже машины с автоматической коробкой передач, нежели автоматической

# %%
data.pivot_table(index=['VehicleType'], 
                 values=['Price'], 
                 aggfunc=np.mean)\
    .sort_values(by='Price',ascending=False)\
    .plot(kind='bar', figsize=(12,6), color='skyblue', edgecolor='black')
plt.xlabel('Бренд')
plt.ylabel('Средняя цена')
plt.title('Средние цена автомобилей c разными типами кузовов');

# %% [markdown]
# Типы кузова suv, convertiblr, coupe, bus в среднем дороже чем другие типы кузовов

# %%
data.pivot_table(index=['FuelType'], 
                 values=['Price'], 
                 aggfunc=np.mean)\
    .sort_values(by='Price',ascending=False)\
    .plot(kind='bar', figsize=(12,6), color='skyblue', edgecolor='black')
plt.xlabel('Бренд')
plt.ylabel('Средняя цена')
plt.title('Средние цена автомобилей c разными типами двигателей');

# %%
data.pivot_table(index=['Repaired'], 
                 values=['Price'], 
                 aggfunc=np.mean)\
    .sort_values(by='Price',ascending=False)\
    .plot(kind='bar', figsize=(12,6), color='skyblue', edgecolor='black')
plt.xlabel('Бренд')
plt.ylabel('Средняя цена')
plt.title('Средние цена автомобилей с ремонтом или без');

# %% [markdown]
# Машины, которые были в ремонте стоят сильно дешевле тех, которые не были в ремонте

# %% [markdown]
# <span style="color:black;font-weight:700;font-size:14px">
#        Корреляцинная матрица
# </span>

# %%
phik_correlation = phik_matrix(data, interval_cols=num_cols)
plot_correlation_matrix(phik_correlation.values,
                       x_labels=phik_correlation.columns,
                       y_labels=phik_correlation.index,
                       vmin=0, vmax=1, 
                       color_map='Greens', 
                       title=r'correlation $\phi_K$',
                       fontsize_factor=1.5,
                       figsize=(16,12))

# %% [markdown]
# Исходя из коррелированности признаков уберем, следующие признаки: PostalCode(почтовый индекс владельца анкеты (пользователя)) так как этот признак не несет для нас полезной информации о цене автомобиля, также удалим признак Model, так как мультиколлинеарен с признаком Brand, также этот признак будет проблематично закодировать, так как он имеет 250 уникальных значений. Также удалим признак RegistrationMonth.

# %%
data = data.drop(columns=['PostalCode', 'Model', 'RegistrationMonth'])

# %%
data.head()
# Out:
#    Price VehicleType  RegistrationYear Gearbox  Power  Kilometer  FuelType  \
# 1  18300       coupe              2011  manual    190     125000  gasoline
# 2   9800         suv              2004    auto    163     125000  gasoline
# 3   1500       small              2001  manual     75     150000    petrol
# 4   3600       small              2008  manual     69      90000  gasoline
# 5    650       sedan              1995  manual    102     150000    petrol
#
#         Brand Repaired
# 1        audi      yes
# 2        jeep       no
# 3  volkswagen       no
# 4       skoda       no
# 5         bmw      yes

# %% [markdown]
# # Подготовка данных

# %% [markdown]
# На данном этапе подготовки реализуем пайплайн обработки данных, который будет включать в себя кодировку категориальных признаков и масштабирование числовых признаков

# %%
y = data['Price']
X = data.drop(columns=['Price'])

RANDOM_STATE = 42

X_train, X_test_valid, y_train, y_test_valid = train_test_split(X,
                                                    y,
                                                    test_size=0.33,
                                                    random_state=RANDOM_STATE)
X_valid, X_test, y_valid, y_test = train_test_split(X_test_valid,
                                                    y_test_valid,
                                                    test_size=0.5,
                                                    random_state=RANDOM_STATE)

# %%
X_train
# Out:
#        VehicleType  RegistrationYear Gearbox  Power  Kilometer  FuelType  \
# 282144         bus              2001  manual    105     150000  gasoline
# 170553       sedan              2017  manual    150     150000    petrol
# 143187       sedan              2017    auto    224     150000    petrol
# 79931          bus              2004  manual     86     150000  gasoline
# 20355        small              2013  manual    122      40000    petrol
# ...            ...               ...     ...    ...        ...       ...
# 160963         bus              2012  manual    165      70000  gasoline
# 347637       sedan              2002  manual    120     150000    petrol
# 177139       small              1990  manual    120     150000    petrol
# 197208       wagon              2007    auto    210     150000    petrol
# 163719       wagon              2012  manual    135      60000    petrol
#
#                 Brand Repaired
# 282144           fiat       no
# ...

# %%
num_columns = ['RegistrationYear', 'Power', 'Kilometer']
ohe_columns = ['VehicleType', 'Gearbox', 'FuelType', 'Brand', 'Repaired']

ohe_pipeline = Pipeline(steps=[
    ('ohe_enocoder', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))])

num_pipeline = Pipeline(steps=[
    ('num_scaler', MinMaxScaler())
])

data_preprocessor = ColumnTransformer([
                                        ('ohe_pipeline', ohe_pipeline, ohe_columns),
                                        ('num_pipeline', num_pipeline, num_columns)
                                       ], remainder='passthrough'
                                    )

# %%
X_train_transform = data_preprocessor.fit_transform(X_train)
X_test_transform = data_preprocessor.transform(X_test)
X_valid_transform = data_preprocessor.transform(X_valid)

# %% [markdown]
# # Обучение моделей

# %%
models = {
    'LGBMRegressor': LGBMRegressor(boosting_type='gbdt', verbose=-100),
    'Catboost': CatBoostRegressor(random_state=RANDOM_STATE, verbose=False),
    'DecisionTree': DecisionTreeRegressor(random_state=RANDOM_STATE),
    'LassoRegression': Lasso(alpha=0.001, random_state=RANDOM_STATE),
    'RidgeRegression': Ridge(alpha=0.001, random_state=RANDOM_STATE),
    'Stochastic Gradient Descent': SGDRegressor(random_state=RANDOM_STATE),
    
    
}


name_column = []
training_time_column = []

for name, model in models.items():
    model_list = []
    start_time = time.time()
    model.fit(X_train_transform,y_train)
    end_time = time.time()
    training_time = end_time - start_time
    name_column.append(name)
    training_time_column.append(training_time)
    print(f'Model {name} - training_time:{training_time}')
    
training_time_df = pd.DataFrame({'Модель': name_column,
                                 'Время обучения, сек': training_time_column}).set_index('Модель')
# Out:
# Model LGBMRegressor - training_time:0.6748442649841309
# Model Catboost - training_time:11.4721097946167
# Model DecisionTree - training_time:1.2545411586761475
# Model LassoRegression - training_time:7.812934160232544
# Model RidgeRegression - training_time:0.2006394863128662
# Model Stochastic Gradient Descent - training_time:3.800809144973755

# %%
training_time_df
# Out:
#                              Время обучения, сек
# Модель
# LGBMRegressor                           0.674844
# Catboost                               11.472110
# DecisionTree                            1.254541
# LassoRegression                         7.812934
# RidgeRegression                         0.200639
# Stochastic Gradient Descent             3.800809

# %%
training_time_df.plot(kind='bar', figsize=(12,6), color='skyblue', edgecolor='black')
plt.xlabel('Модель')
plt.ylabel('Время обучения (сек)')
plt.title('Время обучения различных моделей')
plt.tight_layout() 

for i, value in enumerate(training_time_df.values):
    plt.text(i, value + 0.1, round(float(value),3), ha='center', va='bottom')

plt.show()

# %% [markdown]
# Как можно заметить быстрее всего обучается модель RidgeRegression(Модель линейной регрессии с L2 регуляризацией), дольше всех обучается модель Catboost

# %%
predicting_time_column = []
rmse_column = []

for name, model in models.items():
    start_time = time.time()
    predictions = model.predict(X_valid_transform)
    end_time = time.time()
    predicting_time = end_time - start_time
    predicting_time_column.append(predicting_time)
    rmse = mean_squared_error(y_pred=predictions, y_true= y_valid, squared=False)
    rmse_column.append(rmse)
    print(f'Model {name} - время предсказания - {predicting_time}')
    print(f'Model {name} - RMSE модели - {rmse}')    
    print()
    
predicting_time_df = pd.DataFrame({'Модель': name_column,
                                 'Время предсказания, сек': predicting_time_column}).set_index('Модель')

rmse_df = pd.DataFrame({'Модель': name_column,
                                 'RMSE': rmse_column}).set_index('Модель')
# Out:
# Model LGBMRegressor - время предсказания - 0.07395768165588379
# Model LGBMRegressor - RMSE модели - 1634.0514945475477
#
# Model Catboost - время предсказания - 0.5629699230194092
# Model Catboost - RMSE модели - 1566.6705654779332
#
# Model DecisionTree - время предсказания - 0.022278785705566406
# Model DecisionTree - RMSE модели - 1779.6878241822021
#
# Model LassoRegression - время предсказания - 0.004001617431640625
# Model LassoRegression - RMSE модели - 2541.5317274498407
#
# Model RidgeRegression - время предсказания - 0.0036296844482421875
# Model RidgeRegression - RMSE модели - 2541.531503102414
#
# Model Stochastic Gradient Descent - время предсказания - 0.004006385803222656
# Model Stochastic Gradient Descent - RMSE модели - 2542.39972858964

# %%
predicting_time_df
# Out:
#                              Время предсказания, сек
# Модель
# LGBMRegressor                               0.073958
# Catboost                                    0.562970
# DecisionTree                                0.022279
# LassoRegression                             0.004002
# RidgeRegression                             0.003630
# Stochastic Gradient Descent                 0.004006

# %%
predicting_time_df.plot(kind='bar', figsize=(12,6), color='skyblue', edgecolor='black')
plt.xlabel('Модель')
plt.ylabel('Время предсказания (сек)')
plt.title('Время предсказания различных моделей')
plt.tight_layout() 

for i, value in enumerate(predicting_time_df.values):
    plt.text(i, value + 0.1, round(float(value),3), ha='center', va='bottom')

plt.show()

# %% [markdown]
# Наибольшее время предсказания имеет модель Catboost

# %%
rmse_df
# Out:
#                                     RMSE
# Модель
# LGBMRegressor                1634.051495
# Catboost                     1566.670565
# DecisionTree                 1779.687824
# LassoRegression              2541.531727
# RidgeRegression              2541.531503
# Stochastic Gradient Descent  2542.399729

# %%
rmse_df.plot(kind='bar', figsize=(12,6), color='skyblue', edgecolor='black')
plt.xlabel('Модель')
plt.ylabel('RMSE')
plt.title('RMSE различных моделей')
plt.tight_layout() 

for i, value in enumerate(rmse_df.values):
    plt.text(i, value + 0.1, round(float(value),3), ha='center', va='bottom')

plt.show()

# %%
rmse_df.join(training_time_df).join(predicting_time_df)
# Out:
#                                     RMSE  Время обучения, сек  \
# Модель
# LGBMRegressor                1634.051495             0.674844
# Catboost                     1566.670565            11.472110
# DecisionTree                 1779.687824             1.254541
# LassoRegression              2541.531727             7.812934
# RidgeRegression              2541.531503             0.200639
# Stochastic Gradient Descent  2542.399729             3.800809
#
#                              Время предсказания, сек
# Модель
# LGBMRegressor                               0.073958
# Catboost                                    0.562970
# DecisionTree                                0.022279
# LassoRegression                             0.004002
# RidgeRegression                             0.003630
# Stochastic Gradient Descent                 0.004006

# %% [markdown]
# Как можно заметить из графиков, наилучшие результаты показали модели градиентного бустинга LGBMRegressor и Catboost , остальные модели несмотря на маленькое время обучения и предсказания дают большую ошибку и не удовлетворяют условиям заказчика.

# %% [markdown]
# # Выбор лучшей модели

# %% [markdown]
# Найдем лучшую модель подбором гиперпараметров поиском по сетке и на лучшей модели предскажим тестовые данные.

# %% [markdown]
# <span style="color:black;font-weight:700;font-size:14px">
#               LGBM
# </span>

# %%
lgbm_regressor = LGBMRegressor(verbose=-100, random_state=RANDOM_STATE)

lgbm_param_grid = {'num_leaves':[10, 50, 100], 
                   'learning_rate':[0.001, 0.01, 0.1, 1],
                   'n_estimators': [100, 200, 400, 800]}

lgbm_GridSearch = GridSearchCV(lgbm_regressor,
                               lgbm_param_grid,
                               cv=3,
                               scoring='neg_mean_squared_error')

# %%
# %%time
lgbm_GridSearch.fit(X_train_transform, y_train)
# Out:
# CPU times: total: 12min 36s
# Wall time: 3min 9s
# GridSearchCV(cv=3, estimator=LGBMRegressor(random_state=42, verbose=-100),
#              param_grid={'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'n_estimators': [100, 200, 400, 800],
#                          'num_leaves': [10, 50, 100]},
#              scoring='neg_mean_squared_error')

# %%
lgbm_GridSearch.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 800, 'num_leaves': 100}

# %%
lgbm_best_model = lgbm_GridSearch.best_estimator_

# %%
# %%time
y_pred_lgmb = lgbm_best_model.predict(X_test_transform)
# Out:
# CPU times: total: 2.55 s
# Wall time: 643 ms

# %%
print(f'Предсказание лучшей LGBM модели на тестовой выборке')
mean_squared_error(y_pred=y_pred_lgmb, y_true=y_test, squared=False)
# Out:
# Предсказание лучшей LGBM модели на тестовой выборке
# 1467.658483968458

# %%
catboost_regressor = CatBoostRegressor(verbose=False,random_state=RANDOM_STATE)

catboost_param_grid = {'learning_rate':[0.001, 0.01, 0.1, 1],
                       'iterations': [100, 200, 400, 800]}

catboostGridSearch = GridSearchCV(catboost_regressor,
                                  catboost_param_grid,
                                  cv=3,
                                  n_jobs=-1,
                                  scoring='neg_mean_squared_error')

# %%
# %%time
catboostGridSearch.fit(X_train_transform, y_train)
# Out:
# CPU times: total: 56.9 s
# Wall time: 2min 47s
# GridSearchCV(cv=3,
#              estimator=<catboost.core.CatBoostRegressor object at 0x00000208671E0C90>,
#              n_jobs=-1,
#              param_grid={'iterations': [100, 200, 400, 800],
#                          'learning_rate': [0.001, 0.01, 0.1, 1]},
#              scoring='neg_mean_squared_error')

# %%
catboost_best_model = catboostGridSearch.best_estimator_

# %%
catboostGridSearch.best_params_
# Out:
# {'iterations': 800, 'learning_rate': 0.1}

# %%
# %%time
y_pred_catboost = catboost_best_model.predict(X_test_transform)
# Out:
# CPU times: total: 1.31 s
# Wall time: 1.27 s

# %%
print(f'Предсказание лучшей Catboost модели на тестовой выборке')
mean_squared_error(y_pred=y_pred_catboost, y_true=y_test, squared=False)
# Out:
# Предсказание лучшей Catboost модели на тестовой выборке
# 1551.1135257480498

# %% [markdown]
# <span style="color:black;font-weight:700;font-size:14px">
#               Вывод
# </span>
#
# В ходе работы была выполнена загрузка данных и предварительная обработка датасета, в ходе которой были обработаны пропуски, выбросы в данных, аномальные значения и дубликаты.
#
# После предварительной обработки данных был проведен исследовательский анализ данных, который включал в себя анализ зависимости целевого признака и анализ кореляции. На этом этапе были подобраны наиболее подходящие для обучения признаки
#
# Далее был подготовлен пайплайн обработки данных, который включал в себя масштабирование числовых признаков и кодировку категориальных переменных.
#
# Лучшие метрику качества на тестовых данных показала LGBM модель (RMSE= 1467), данная модель является предпочтительнее исходя из условий заказчика, так эта модель быстрее обучается, быстрее предсказывает результаты и ее метрика не сильно хуже метрики модели Catboost, а при более подробном подборе гиперпараметров показывает лучший результат. Параметры данной модели - {'learning_rate': 0.1, 'n_estimators': 800, 'num_leaves': 100}
